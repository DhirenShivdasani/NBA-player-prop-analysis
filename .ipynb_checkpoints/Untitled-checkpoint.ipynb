# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
import pandas as pd
import itertools
import numpy as np

# Assuming 'data' is your DataFrame and includes a column for minutes ('MIN')
# Create a simplified DataFrame for analysis
simplified_data = data[['Game_ID', 'Player_ID', 'Team', 'AST', 'PTS', 'MIN']]

# Calculate the average minutes per game for each player
average_minutes = simplified_data.groupby('Player_ID')['MIN'].mean()

# Filter players who average 10+ minutes per game
players_with_10_plus_minutes = average_minutes[average_minutes >= 10].index.tolist()
simplified_data = simplified_data[simplified_data['Player_ID'].isin(players_with_10_plus_minutes)]

# Initialize a dictionary to store assists and points for each player pair in each team
pair_stats = {}

# Get unique game IDs
game_ids = simplified_data['Game_ID'].unique()

# Looping through each game
for game_id in game_ids:
    game_subset = simplified_data[simplified_data['Game_ID'] == game_id]

    # Grouping players by team
    for team, team_subset in game_subset.groupby('Team'):
        # Create pairs of players within the team
        player_pairs = itertools.combinations(team_subset['Player_ID'], 2)

        # Loop through each pair and aggregate their assists and points
        for pair in player_pairs:
            player_a, player_b = pair
            assists_a = team_subset[team_subset['Player_ID'] == player_a]['AST'].sum()
            points_b = team_subset[team_subset['Player_ID'] == player_b]['PTS'].sum()

            pair_key = (team, player_a, player_b)

            if pair_key not in pair_stats:
                pair_stats[pair_key] = {'assists': [], 'points': []}

            pair_stats[pair_key]['assists'].append(assists_a)
            pair_stats[pair_key]['points'].append(points_b)

# Mapping player IDs to names
player_id_to_name = data[['Player_ID', 'PlayerName']].drop_duplicates().set_index('Player_ID')['PlayerName'].to_dict()

# Calculate correlation for each player pair within the same team
pairwise_correlations = []
for key, values in pair_stats.items():
    team, player_a, player_b = key
    if len(values['assists']) > 1 and len(values['points']) > 1:  # Ensure enough data for correlation
        correlation = np.corrcoef(values['assists'], values['points'])[0, 1]
        pairwise_correlations.append({
            'Team': team,
            'Player_A_ID': player_a,
            'Player_B_ID': player_b,
            'Correlation': correlation
        })

# Convert to DataFrame and sort by correlation
pairwise_correlations_df = pd.DataFrame(pairwise_correlations)
pairwise_correlations_df.sort_values(by='Correlation', ascending=False, inplace=True)

# Adding player names
pairwise_correlations_df['Player_A_Name'] = pairwise_correlations_df['Player_A_ID'].map(player_id_to_name)
pairwise_correlations_df['Player_B_Name'] = pairwise_correlations_df['Player_B_ID'].map(player_id_to_name)

# Displaying top correlations
top_correlations = pairwise_correlations_df[['Team', 'Player_A_Name', 'Player_B_Name', 'Correlation']].head()
# Out:
# /Users/dhirenshivdasani/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/dhirenshivdasani/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
pairwise_correlations_df[pairwise_correlations_df['Team'] == 'TOR'].head(25)
# Out:
#      Team  Player_A_ID  Player_B_ID  Correlation      Player_A_Name  \
# 1881  TOR      1630567      1630193     0.921765     Scottie Barnes
# 1887  TOR      1629628      1629018     0.705089         RJ Barrett
# 276   TOR      1630173      1630201     0.567715   Precious Achiuwa
# 310   TOR      1627751      1627783     0.555868       Jakob Poeltl
# 299   TOR      1628449       203490     0.532670      Chris Boucher
# 1892  TOR      1630193      1629018     0.523971  Immanuel Quickley
# 1882  TOR      1629628      1628449     0.364797         RJ Barrett
# 311   TOR      1627751      1629018     0.362641       Jakob Poeltl
# 288   TOR      1628384      1627783     0.288152         OG Anunoby
# 309   TOR      1627751       203471     0.275493       Jakob Poeltl
# 290   TOR      1630567      1628449     0.264776     Scottie Barnes
# 305   TOR      1630201       203471     0.263703      Malachi Flynn
# 1888  TOR      1628449      1630193     0.249949      Chris Boucher
# ...

# %%
# injury_data = pd.read_csv('injury_data.csv')
# injury_data = injury_data.rename(columns = {'Player':'PlayerName'})
# injury_data.drop(['Team'], axis = 1, inplace = True)
# merged_data = data.merge(injury_data, on ='PlayerName', how = 'left')

# %%
data = pd.read_csv('all_data.csv')
test2_df = pd.read_csv('test2.csv')
test2_df = test2_df.rename(columns = {'Name':'PlayerName'})
test2_df.drop(['Unnamed: 0','Team'], axis =1, inplace = True)

# Merge the dataframes on the player's name
merged_data = pd.merge(data, test2_df, on='PlayerName', how = 'left')
relevant_props = ['Points', 'Assists', 'Rebounds', 'Pts+Rebs+Asts', 'Pts+Asts', 'Pts+Rebs', 'Rebs+Asts']

merged_data['Pts+Rebs+Asts'] = merged_data['PTS'] + merged_data['REB'] + merged_data['AST']
merged_data['Pts+Rebs'] = merged_data['PTS'] + merged_data['REB']
merged_data['Pts+Asts'] = merged_data['PTS'] + merged_data['AST']
merged_data['Rebs+Asts'] = merged_data['REB'] + merged_data['AST']
merged_data= merged_data.rename(columns = {'PTS':'Points', 'REB': 'Rebounds', 'AST': 'Assists'})
# merged_data = merged_data[merged_data['Prop'].isin(relevant_props)]
merged_data.to_csv('merged_data.csv', index = False)

# %%
un_d = merged_data['GAME_DATE'].unique()

# %%
player_data = merged_data[(merged_data['PlayerName'] == 'OG Anunoby') & (merged_data['Prop'] == 'Points')]


# Filter for the specific opponent if selected
player_data = player_data[(player_data['Home'] == 'CHA') | (player_data['Away'] == 'CHA')]
player_data
# Out:
#       SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 1149      22023    1628384  22300354  DEC 18, 2023  TOR vs. CHA  W   32    2
# 1173      22023    1628384  22301216  DEC 08, 2023    TOR @ CHA  L   36    3
#
#       FGA  FG_PCT  ...  Team  Home  Away  Value    Prop  Pts+Rebs+Asts  \
# 1149   10    0.20  ...   TOR   TOR   CHA   14.0  Points              9
# 1173   12    0.25  ...   TOR   CHA   TOR   14.0  Points             18
#
#       Pts+Rebs  Pts+Asts  Rebs+Asts  Prop_Result
# 1149         7         7          4         -1.0
# 1173        14        15          7         -1.0
#
# [2 rows x 38 columns]

# %%
unique_player_props = merged_data[['PlayerName', 'Prop', 'Value']]

# List of relevant prop types - ensure these match exactly with your data
relevant_props = ["Points", "Assists", "Rebounds", "Pts+Rebs+Asts", 'Pts+Rebs', 'Pts+Asts', 'Rebs+Asts']

# Filter the DataFrame to include only relevant prop types
unique_player_props = unique_player_props[unique_player_props['Prop'].isin(relevant_props)]

# Check if the resulting DataFrame is empty
if unique_player_props.empty:
    print("No matching props found in the DataFrame.")
else:
    print("Filtered props:")
    print(unique_player_props)
# Out:
# Filtered props:
#           PlayerName           Prop  Value
# 162    Grayson Allen         Points   12.5
# 163    Grayson Allen       Rebounds    4.0
# 164    Grayson Allen  Pts+Rebs+Asts   19.5
# 165    Grayson Allen       Pts+Rebs   16.5
# 166    Grayson Allen       Pts+Asts   15.5
# ...              ...            ...    ...
# 17946      Dean Wade       Rebounds    4.0
# 17947      Dean Wade       Rebounds    4.0
# 17948      Dean Wade       Rebounds    4.0
# 17949      Dean Wade       Rebounds    4.0
# 17950      Dean Wade       Rebounds    4.0
#
# [6981 rows x 3 columns]

# %%
unique_player_props
# Out:
# Empty DataFrame
# Columns: [PlayerName, Prop, Value]
# Index: []

# %%
import datetime as dt
merged_data['GAME_DATE'] = pd.to_datetime(merged_data['GAME_DATE'])

merged_data['GAME_DATE'].dt.strftime('%m-%d-%y')
# Out:
# 0        01-11-24
# 1        01-09-24
# 2        01-06-24
# 3        01-05-24
# 4        01-03-24
#            ...
# 27517    10-25-23
# 27518    10-25-23
# 27519    10-25-23
# 27520    10-25-23
# 27521    10-25-23
# Name: GAME_DATE, Length: 27522, dtype: object

# %%
merged_data[merged_data['Team'] == 'CHA'].sort_values(by ='GAME_DATE').tail(10)
# Out:
#        SEASON_ID  Player_ID   Game_ID  GAME_DATE      MATCHUP WL  MIN  FGM  \
# 15995      22023    1641706  22300518 2024-01-10  CHA vs. SAC  L   28    5
# 15996      22023    1641706  22300518 2024-01-10  CHA vs. SAC  L   28    5
# 15814      22023    1631121  22300518 2024-01-10  CHA vs. SAC  L   10    1
# 21788      22023    1641733  22300518 2024-01-10  CHA vs. SAC  L   25    4
# 2434       22023    1628970  22300518 2024-01-10  CHA vs. SAC  L   34   10
# 15993      22023    1641706  22300518 2024-01-10  CHA vs. SAC  L   28    5
# 15997      22023    1641706  22300518 2024-01-10  CHA vs. SAC  L   28    5
# 15994      22023    1641706  22300518 2024-01-10  CHA vs. SAC  L   28    5
# 19420      22023    1630208  22300518 2024-01-10  CHA vs. SAC  L   26    3
# 2315       22023    1630547  22300518 2024-01-10  CHA vs. SAC  L   20    3
#
#        FGA  FG_PCT  ...  Team  Home  Away  Value           Prop  \
# 15995   10   0.500  ...   CHA   CHA   SAC   22.5  Pts+Rebs+Asts
# ...

# %%
def get_player_absences(dataframe, player_name, team):
    # Filter games where the player's team played
    team_games = dataframe[dataframe['Team'] == team]['Game_ID'].unique()

    # Check if the player participated in each of these games
    player_absences = []
    for game in team_games:
        if not dataframe[(dataframe['Game_ID'] == game) & (dataframe['PlayerName'] == player_name)].empty:
            continue  # Player participated in this game
        player_absences.append(game)  # Player was absent for this game

    return player_absences

# %%
def analyze_prop_bet_enhanced(dataframe, player_name, team, opponent, injured_players, value, prop_type_adjusted):
    """
    Analyzes a player's prop bet considering various factors including home vs. away performance, 
    opponent's stats, and the impact of multiple teammates' absences.
    """
    # Filter data for the specified player and team
    player_data = dataframe[(dataframe['PlayerName'] == player_name)]

    # Check if there is enough data for analysis
    if player_data.empty:
        return f"No data available for player {player_name}."

    # Adjust prop_type to match column names in the dataframe

    all_injured_players_out_dates = set()
    for injured_player in injured_players:
        injured_player_out_dates = set(dataframe[(dataframe['PlayerName'] == injured_player)]['Game_ID'].unique())
        all_injured_players_out_dates.update(injured_player_out_dates)

    # Convert the set to a list for filtering
    unique_injured_players_out_dates = list(all_injured_players_out_dates)



    historical_performance_against_opponent = player_data[(player_data['Away'] == opponent) | (player_data['Home'] == opponent)][prop_type_adjusted]

    player_avg_minutes =  player_data['MIN'].mean()
    player_avg_minutes_with_teammates_out = player_data[player_data['Game_ID'].isin(unique_injured_players_out_dates)]['MIN'].mean()

    

    # Calculate player's performance with teammates out
    player_performance_with_teammates_out = player_data[player_data['Game_ID'].isin(unique_injured_players_out_dates)][prop_type_adjusted].mean()

    home_games = player_data[player_data['Home'] == team]
    away_games = player_data[player_data['Away'] == team]

    win_percentage_home = home_games['WL'].value_counts(normalize=True).get('W', 0) * 100
    win_percentage_away = away_games['WL'].value_counts(normalize=True).get('W', 0) * 100

    
    # Analysis based on the prop type
    if prop_type_adjusted in player_data.columns:
        # average_with_teammates_out = player_performance_with_teammates_out.mean()
        average_overall = player_data[prop_type_adjusted].mean()
        std_dev = player_data[prop_type_adjusted].std()
        average_home = player_data[player_data['Home'] == team][prop_type_adjusted].mean()
        average_away = player_data[player_data['Away'] == team][prop_type_adjusted].mean()
        average_against_opponent = historical_performance_against_opponent.mean()

        # Opponent stats analysis
        opponent_stat_given = None
        team_stat_given = None
        player_stat_given = None
        PER_given = None

        if prop_type_adjusted == 'Rebounds':
            team_data = pd.read_csv('team_stats/total-rebounds-per-game_data.csv')
            team_stat_given = team_data[team_data['Team'] == team]['Rank'].values[0]
            opponent_data = pd.read_csv('team_stats/opponent-total-rebounds-per-game_data.csv')
            opponent_stat_given = opponent_data[opponent_data['Team'] == opponent]['Rank'].values[0]
            player_stat = pd.read_csv('player_stats/rebounds_data.csv')
            if player_name in player_stat['Player'].values:
                player_stat_given = player_stat[player_stat['Player'] == player_name]['Rank'].values[0]
            else:
                print(f'{player_name} rank not available')
                player_stat_given = None
        elif prop_type_adjusted == 'Assists':
            opponent_data = pd.read_csv('team_stats/opponent-assists-per-game_data.csv')
            opponent_stat_given = opponent_data[opponent_data['Team'] == opponent]['Rank'].values[0]
            team_data = pd.read_csv('team_stats/assists-per-game_data.csv')
            team_stat_given = team_data[team_data['Team'] == team]['Rank'].values[0]
            player_stat = pd.read_csv('player_stats/assists_data.csv')
            if player_name in player_stat['Player'].values:
                player_stat_given = player_stat[player_stat['Player'] == player_name]['Rank'].values[0]
            else:
                print(f'{player_name} rank not available')
                player_stat_given = None

        elif prop_type_adjusted == 'Points':
            opponent_data = pd.read_csv('team_stats/opponent-points-per-game_data.csv')
            opponent_stat_given = opponent_data[opponent_data['Team'] == opponent]['Rank'].values[0]
            team_data = pd.read_csv('team_stats/points-per-game_data.csv')
            team_stat_given = team_data[team_data['Team'] == team]['Rank'].values[0]
            player_stat = pd.read_csv('player_stats/points_data.csv')
            PER= pd.read_csv('player_stats/nba-efficiency_data.csv')
            TSP = pd.read_csv('player_stats/ts-percentage_data.csv')

            if player_name in player_stat['Player'].values:
                player_stat_given = player_stat[player_stat['Player'] == player_name]['Rank'].values[0]
                PER_given = PER[PER['Player'] == player_name]['Value'].values[0]
            else:
                print(f'{player_name} rank not available')
                player_stat_given = None
                PER_given = None
                
        elif prop_type_adjusted == 'Pts+Rebs+Asts':
            opponent_data = pd.read_csv('team_stats/opponent-points-plus-rebounds-plus-assists-per-gam_data.csv')
            opponent_stat_given = opponent_data[opponent_data['Team'] == opponent]['Rank'].values[0]
            team_data = pd.read_csv('team_stats/points-plus-rebounds-plus-assists-per-game_data.csv')
            team_stat_given = team_data[team_data['Team'] == team]['Rank'].values[0]
            player_stat = pd.read_csv('player_stats/points-plus-rebounds-plus-assists_data.csv')

            if player_name in player_stat['Player'].values:
                player_stat_given = player_stat[player_stat['Player'] == player_name]['Rank'].values[0]
            else:
                print(f'{player_name} rank not available')
                player_stat_given = None
                
        elif prop_type_adjusted == 'Pts+Rebs':
            opponent_data = pd.read_csv('team_stats/opponent-points-plus-rebounds-per-game_data.csv')
            opponent_stat_given = opponent_data[opponent_data['Team'] == opponent]['Rank'].values[0]
            team_data = pd.read_csv('team_stats/points-plus-rebounds-per-game_data.csv')
            team_stat_given = team_data[team_data['Team'] == team]['Rank'].values[0]
            player_stat = pd.read_csv('player_stats/points-plus-rebounds_data.csv')

            if player_name in player_stat['Player'].values:
                player_stat_given = player_stat[player_stat['Player'] == player_name]['Rank'].values[0]
            else:
                print(f'{player_name} rank not available')
                player_stat_given = None
        elif prop_type_adjusted == 'Pts+Asts':
            opponent_data = pd.read_csv('team_stats/opponent-points-plus-assists-per-game_data.csv')
            opponent_stat_given = opponent_data[opponent_data['Team'] == opponent]['Rank'].values[0]
            team_data = pd.read_csv('team_stats/points-plus-assists-per-game_data.csv')
            team_stat_given = team_data[team_data['Team'] == team]['Rank'].values[0]
            player_stat = pd.read_csv('player_stats/points-plus-assists_data.csv')

            if player_name in player_stat['Player'].values:
                player_stat_given = player_stat[player_stat['Player'] == player_name]['Rank'].values[0]
            else:
                print(f'{player_name} rank not available')
                player_stat_given = None

        elif prop_type_adjusted == 'Rebs+Asts':
            opponent_data = pd.read_csv('team_stats/opponent-rebounds-plus-assists-per-game_data.csv')
            opponent_stat_given = opponent_data[opponent_data['Team'] == opponent]['Rank'].values[0]
            team_data = pd.read_csv('team_stats/rebounds-plus-assists-per-game_data.csv')
            team_stat_given = team_data[team_data['Team'] == team]['Rank'].values[0]
            player_stat = pd.read_csv('player_stats/rebounds-plus-assist_data.csv')

            if player_name in player_stat['Player'].values:
                player_stat_given = player_stat[player_stat['Player'] == player_name]['Rank'].values[0]
            else:
                print(f'{player_name} rank not available')
                player_stat_given = None
        

        # Final results including all factors
        results = {
            'Minutes Per Game':player_avg_minutes.round(1),
            'Field Goal %:': (player_data['FG_PCT'].mean()*100).round(0),
            '3PT Field Goal %:': (player_data['FG3_PCT'].mean()*100).round(0),
            'Free Throw %:': (player_data['FT_PCT'].mean()*100).round(0),
            f'average_minutes_with{injured_players}_out': player_avg_minutes_with_teammates_out,
            f'average_with_{injured_players}_out': player_performance_with_teammates_out,
            f'average_{prop_type_adjusted}_overall': average_overall.round(0),
            'std_dev': std_dev,
            f'average_{prop_type_adjusted}_home': average_home.round(0),
            f'average_{prop_type_adjusted}_away': average_away.round(0),
            f'average_{prop_type_adjusted}_against_opponent': average_against_opponent,
            f'average_{prop_type_adjusted}_with_teammates_out' : player_performance_with_teammates_out,
            'impact_on_performance': (player_performance_with_teammates_out - average_overall).round(1),
            f'above_{prop_type_adjusted}_with_teammates_out': player_performance_with_teammates_out > value,
            f'above_{prop_type_adjusted}_overall': average_overall > value,
            'win_percentage_home': f"{win_percentage_home:.2f}%",
            'win_percentage_away': f"{win_percentage_away:.2f}%"
        }

        if opponent_stat_given is not None:
            results[f'{opponent}_{prop_type_adjusted.lower()}_defense_rank (Out of 30)'] = opponent_stat_given
        if team_stat_given is not None:
            results[f'{team}_{prop_type_adjusted.lower()}_rank (Out of 30)'] = team_stat_given
        if player_stat_given is not None:
            results[f'{player_name}_{prop_type_adjusted.lower()}_rank (Out of 100)'] = player_stat_given
        if player_stat_given is not None:
            results[f'{player_name} Efficiency Rating %'] = PER_given
            

        return results
    else:
        return f"Prop type '{prop_type_adjusted}' not found in data."

# %%
enhanced_analysis_results = analyze_prop_bet_enhanced(merged_data, 'Derrick Jones Jr.', 'DAL', 'NYK', ['Rui Hachimura'], 9.5, 'Points')
enhanced_analysis_results
# Out:
# Derrick Jones Jr. rank not available
# {'Minutes Per Game': 26.0,
#  'Field Goal %:': 47.0,
#  '3PT Field Goal %:': 30.0,
#  'Free Throw %:': 48.0,
#  "average_minutes_with['Rui Hachimura']_out": 19.0,
#  "average_with_['Rui Hachimura']_out": 6.0,
#  'average_Points_overall': 11.0,
#  'std_dev': 6.800214333368993,
#  'average_Points_home': 12.0,
#  'average_Points_away': 9.0,
#  'average_Points_against_opponent': 9.0,
#  'average_Points_with_teammates_out': 6.0,
#  'impact_on_performance': -4.6,
#  'above_Points_with_teammates_out': False,
#  'above_Points_overall': True,
#  'win_percentage_home': '55.00%',
#  'win_percentage_away': '57.89%',
#  'NYK_points_defense_rank (Out of 30)': 7,
#  'DAL_points_rank (Out of 30)': 7}

# %%
player_data = merged_data[(merged_data['PlayerName'] == 'Josh Giddey') ]['Team']

# %%
.sort_values('GAME_DATE', ascending=False).tail(10)
# Out:
# 'OKC'

# %%
merged_data = pd.read_csv('merged_data.csv')

# %%
def prop_result(row):
    if row['Prop'] == 'Points':
        performance = row['Points']
    elif row['Prop'] == 'Assists':
        performance = row['Assists']
    elif row['Prop'] == 'Rebounds':
        performance = row['Rebounds']
    elif row['Prop'] == 'Pts+Rebs+Asts':
        performance = row['Points'] + row['Rebounds'] + row['Assists']
    elif row['Prop'] == 'Pts+Asts':
        performance = row['Points'] + row['Assists']
    elif row['Prop'] == 'Pts+Rebs':
        performance = row['Points'] + row['Rebounds']
    elif row['Prop'] == 'Rebs+Asts':
        performance = row['Rebounds'] + row['Assists']
    else:
        return None  # Undefined prop type

    if performance > row['Value']:
        return 1  # Over
    elif performance < row['Value']:
        return -1  # Under
    else:
        return 0  # Exact



# Apply the functions to each row
merged_data['Prop_Result'] = merged_data.apply(prop_result, axis=1)

# Group by PlayerName, Team, Value, and Prop
grouped = merged_data.groupby(['PlayerName', 'Team', 'Value', 'Prop'])

# Calculate aggregated statistics
grouped_stats = grouped['Prop_Result'].value_counts(normalize=True).unstack(fill_value=0) * 100



# Rename columns for clarity in Prop_Result
grouped_stats = grouped_stats.rename(columns={-1: 'Under %', 0: 'Exact %', 1: 'Over %', 'Deviation': 'Std Deviation'})

# Reset the index to turn the group by columns into regular columns
grouped_stats = grouped_stats.reset_index()

# %%
grouped_stats.sort_values(by='Over %', ascending=False).head(60)
# Out:
# Prop_Result                PlayerName Team  Value           Prop    Under %  \
# 56                    Cameron Johnson  BKN   18.5  Pts+Rebs+Asts  23.529412
# 52                    Cameron Johnson  BKN   14.5       Pts+Asts  26.470588
# 54                    Cameron Johnson  BKN    3.5       Rebounds  26.470588
# 87                Dorian Finney-Smith  BKN   11.5       Pts+Rebs  30.769231
# 89                Dorian Finney-Smith  BKN    6.5         Points  30.769231
# 131                 Jonas Valanciunas  NOP   20.5       Pts+Rebs  32.558140
# 133                 Jonas Valanciunas  NOP   23.5  Pts+Rebs+Asts  32.558140
# 130                 Jonas Valanciunas  NOP   10.5      Rebs+Asts  32.558140
# 79                      Deandre Ayton  POR   10.0      Rebs+Asts  34.615385
# 55                    Cameron Johnson  BKN   12.5         Points  35.294118
# 50                         Cam Thomas  BKN   19.5       Pts+Asts  36.363636
# ...

# %% [markdown]
# ## Player Game Logs

# %%
injury_data = pd.read_csv('injury_data.csv')

# Parse injury data to find out players who are 'Out' and 'Day to Day'
out_players = injury_data[injury_data['Details'].str.contains('Out')]['Player'].tolist()
day_to_day_players = injury_data[injury_data['Details'].str.contains('Day To Day')]['Player'].tolist()

# %%
day_to_day_players
# Out:
# ['Brandon Miller',
#  'Frank Ntilikina',
#  'Ayo Dosunmu',
#  'Dalen Terry',
#  'Patrick Williams',
#  'Max Strus',
#  'Bruce Brown',
#  'Aaron Nesmith',
#  'Ivica Zubac',
#  'Anthony Davis',
#  'LeBron James',
#  "D'Angelo Russell",
#  'Santi Aldama',
#  'Jaren Jackson Jr.',
#  'Jimmy Butler',
#  'Kyle Lowry',
#  'Chris Livingston',
#  'Shai Gilgeous-Alexander',
#  'Mo Bamba',
#  'Robert Covington',
#  'Kenneth Lofton Jr.',
#  'Jaden Springer',
#  'Bol Bol',
#  'Deandre Ayton',
#  'Ibou Badji',
#  'Malcolm Brogdon',
#  'Jerami Grant',
#  'Shaedon Sharpe',
#  'Matisse Thybulle',
#  'Keegan Murray',
#  'Gradey Dick']

# %%
team_scores = data.groupby(['Game_ID', 'Team'])['PTS'].sum().reset_index()

# %%
t = pd.merge(data, team_scores, on=['Game_ID', 'Team'], suffixes=('', '_Team_Total'))
t
# Out:
#        SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0          22023    1630173  22300573  JAN 17, 2024  NYK vs. HOU  W    6    0
# 1          22023    1628384  22300573  JAN 17, 2024  NYK vs. HOU  W   43    5
# 2          22023    1627853  22300573  JAN 17, 2024  NYK vs. HOU  W    1    0
# 3          22023    1628973  22300573  JAN 17, 2024  NYK vs. HOU  W   37   11
# 4          22023    1628978  22300573  JAN 17, 2024  NYK vs. HOU  W   19    2
# ...          ...        ...       ...           ...          ... ..  ...  ...
# 12995      22023    1630171  22300120  NOV 01, 2023    CLE @ NYK  W   31    1
# 12996      22023    1641854  22300120  NOV 01, 2023    CLE @ NYK  W   11    1
# 12997      22023    1629622  22300120  NOV 01, 2023    CLE @ NYK  W   35    3
# 12998      22023     202684  22300120  NOV 01, 2023    CLE @ NYK  W   13    3
# 12999      22023    1629731  22300120  NOV 01, 2023    CLE @ NYK  W   20    2
#
# ...

# %%
data = pd.read_csv('all_data.csv')
team_scores = data.groupby(['Game_ID', 'Team'])['PTS'].sum().reset_index()
data= pd.merge(data, team_scores, on=['Game_ID', 'Team'], suffixes=('', '_Team_Total'))
test2_df = pd.read_csv('test2.csv')
test2_df = test2_df.rename(columns = {'Name':'PlayerName'})
test2_df.drop(['Unnamed: 0','Team'], axis =1, inplace = True)

# Merge the dataframes on the player's name
merged_data = pd.merge(data, test2_df, on='PlayerName', how = 'left')

merged_data['Pts+Rebs+Asts'] = merged_data['PTS'] + merged_data['REB'] + merged_data['AST']
merged_data['Pts+Rebs'] = merged_data['PTS'] + merged_data['REB']
merged_data['Pts+Asts'] = merged_data['PTS'] + merged_data['AST']
merged_data['Rebs+Asts'] = merged_data['REB'] + merged_data['AST']
merged_data= merged_data.rename(columns = {'PTS':'Points', 'REB': 'Rebounds', 'AST': 'Assists'})
merged_data.to_csv('merged_data.csv', index = False)

dataframe = pd.read_csv('merged_data.csv')

# %%
dataframe
# Out:
#        SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0          22023    1630173  22300573  JAN 17, 2024  NYK vs. HOU  W    6    0
# 1          22023    1628384  22300573  JAN 17, 2024  NYK vs. HOU  W   43    5
# 2          22023    1628384  22300573  JAN 17, 2024  NYK vs. HOU  W   43    5
# 3          22023    1628384  22300573  JAN 17, 2024  NYK vs. HOU  W   43    5
# 4          22023    1628384  22300573  JAN 17, 2024  NYK vs. HOU  W   43    5
# ...          ...        ...       ...           ...          ... ..  ...  ...
# 27368      22023    1630171  22300120  NOV 01, 2023    CLE @ NYK  W   31    1
# 27369      22023    1641854  22300120  NOV 01, 2023    CLE @ NYK  W   11    1
# 27370      22023    1629622  22300120  NOV 01, 2023    CLE @ NYK  W   35    3
# 27371      22023     202684  22300120  NOV 01, 2023    CLE @ NYK  W   13    3
# 27372      22023    1629731  22300120  NOV 01, 2023    CLE @ NYK  W   20    2
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the webpage you want to scrape
html = '''<table id="nba_table" class="display nowrap dataTable no-footer dtfc-has-left" style="width: 100%; font-size: 12px;"><thead>
                                <tr style="height: 0px;"><th class="sorting_disabled dtfc-fixed-left sorting_asc" rowspan="1" colspan="1" style="width: 4px; left: 0px; position: sticky; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" aria-label=""><div class="dataTables_sizing" style="height: 0px; overflow: hidden;"></div></th><th class="sorting_disabled" rowspan="1" colspan="1" style="width: 143.906px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" aria-label="Player Name"><div class="dataTables_sizing" style="height: 0px; overflow: hidden;">Player Name</div></th><th class="sorting_disabled" rowspan="1" colspan="1" style="width: 79.8281px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" aria-label="Date"><div class="dataTables_sizing" style="height: 0px; overflow: hidden;">Date</div></th><th class="sorting_disabled" rowspan="1" colspan="1" style="width: 268.398px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" aria-label="Match Up"><div class="dataTables_sizing" style="height: 0px; overflow: hidden;">Match Up</div></th><th class="sorting_disabled" rowspan="1" colspan="1" style="width: 192.961px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" aria-label="Market Name"><div class="dataTables_sizing" style="height: 0px; overflow: hidden;">Market Name</div></th><th class="sorting_disabled" rowspan="1" colspan="1" style="width: 33.7031px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" aria-label="O/U"><div class="dataTables_sizing" style="height: 0px; overflow: hidden;">O/U</div></th><th class="sorting_disabled" rowspan="1" colspan="1" style="width: 50.3047px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" aria-label="PrizePicks"><div class="dataTables_sizing" style="height: 0px; overflow: hidden;"><a alt="PrizePicks" href="https://prizepicks.onelink.me/ivHR/DONUTS" style="font-size:10px;color:#ffffff;"><img style="width: 28px;height:28px;" src="https://myspariedge.com/logos/PrizePicks.jpg" title="PrizePicks"><br>PrizePicks</a></div></th><th style="font-size: 10px; color: rgb(255, 255, 255); width: 40.5234px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" class="sorting_disabled" rowspan="1" colspan="1" aria-label="Prob%"><div class="dataTables_sizing" style="height: 0px; overflow: hidden;">Prob%</div></th><th style="font-size: 10px; color: rgb(255, 255, 255); width: 40.5859px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" class="sorting_disabled" rowspan="1" colspan="1" aria-label="MySpari
                                    "><div class="dataTables_sizing" style="height: 0px; overflow: hidden;"><img src="https://myspariedge.com/logos/MySpari.png" title="MySpari"><br>MySpari
                                    </div></th><th style="font-size: 10px; color: rgb(255, 255, 255); width: 24.4453px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" class="sorting_disabled" rowspan="1" colspan="1" aria-label="Fliff
                                    "><div class="dataTables_sizing" style="height: 0px; overflow: hidden;"><img src="https://myspariedge.com/logos/Fliff.png" title="Fliff"><br>Fliff
                                    </div></th><th style="font-size: 10px; color: rgb(255, 255, 255); width: 53.0859px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" class="sorting_disabled" rowspan="1" colspan="1" aria-label="DraftKings"><div class="dataTables_sizing" style="height: 0px; overflow: hidden;"><img src="https://myspariedge.com/logos/DraftKings.png" title="DraftKings"><br>DraftKings</div></th><th style="font-size: 10px; color: rgb(255, 255, 255); width: 41.0391px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" class="sorting_disabled" rowspan="1" colspan="1" aria-label="FanDuel
                                    "><div class="dataTables_sizing" style="height: 0px; overflow: hidden;"><img src="https://myspariedge.com/logos/FanDuel.png" title="FanDuel"><br>FanDuel
                                    </div></th><th style="font-size: 10px; color: rgb(255, 255, 255); width: 38.8438px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" class="sorting_disabled" rowspan="1" colspan="1" aria-label="Caesars
                                    "><div class="dataTables_sizing" style="height: 0px; overflow: hidden;"><img src="https://myspariedge.com/logos/Caesars.png" title="Caesars"><br>Caesars
                                    </div></th><th style="font-size: 10px; color: rgb(255, 255, 255); width: 43.0703px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" class="sorting_disabled" rowspan="1" colspan="1" aria-label="BetMGM
                                    "><div class="dataTables_sizing" style="height: 0px; overflow: hidden;"><img src="https://myspariedge.com/logos/BetMGM.png" title="BetMGM"><br>BetMGM
                                    </div></th><th style="font-size: 10px; color: rgb(255, 255, 255); width: 42.6172px; padding-top: 0px; padding-bottom: 0px; border-top-width: 0px; border-bottom-width: 0px; height: 0px;" class="sorting_disabled" rowspan="1" colspan="1" aria-label="Pinnacle"><div class="dataTables_sizing" style="height: 0px; overflow: hidden;"><img src="https://myspariedge.com/logos/Pinnacle.png" title="Pinnacle"><br>Pinnacle</div></th></tr>
                            </thead>
                            <tbody><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>CJ McCollum</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds</td><td>under</td><td>4</td><td>59.89%</td><td>4.4<br>-149</td><td>4.5<br>-170<br></td><td>4.5<br>-145<br></td><td>4.5<br>-152<br></td><td>4.5<br>-154<br></td><td>4.5<br>-150<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Zion Williamson</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Assists</td><td>over</td><td>5</td><td>59.86%</td><td>4.6<br>-149</td><td>4.5<br>-145<br></td><td>4.5<br>-145<br></td><td>4.5<br>-160<br></td><td>4.5<br>-157<br></td><td></td><td>4.5<br>-158<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Malcolm Brogdon</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds</td><td>over</td><td>4</td><td>59.68%</td><td>3.7<br>-148</td><td>3.5<br>-175<br></td><td>3.5<br>-150<br></td><td>3.5<br>-152<br></td><td>3.5<br>-157<br></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kawhi Leonard</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds</td><td>under</td><td>6</td><td>59.66%</td><td>6.4<br>-148</td><td>6.5<br>-170<br></td><td>6.5<br>-145<br></td><td>6.5<br>-132<br></td><td>6.5<br>-151<br></td><td>6.5<br>-155<br></td><td>6.5<br>-156<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Williams</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds</td><td>under</td><td>4</td><td>59.65%</td><td>4.4<br>-148</td><td>4.5<br>-165<br></td><td>4.5<br>-145<br></td><td>4.5<br>-144<br></td><td>4.5<br>-157<br></td><td>4.5<br>-150<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anthony Davis</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Assists</td><td>under</td><td>4</td><td>59.53%</td><td>4.4<br>-147</td><td>4.5<br>-165<br></td><td>4.5<br>-130<br></td><td>4.5<br>-140<br></td><td>4.5<br>-148<br></td><td>4.5<br>-150<br></td><td>4.5<br>-170<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jabari Walker</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds</td><td>under</td><td>7</td><td>58.98%</td><td>7.3<br>-144</td><td>7.5<br>-155<br></td><td>7.5<br>-140<br></td><td>7.5<br>-142<br></td><td>7.5<br>-142<br></td><td>7.5<br>-140<br></td><td>7.5<br>-173<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Pascal Siakam</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Rebounds + Assists</td><td>over</td><td>10</td><td>58.94%</td><td>9.8<br>-144</td><td>9.5<br>-155<br></td><td>9.5<br>-140<br></td><td>10.5<br>-102<br></td><td>9.5<br>-189<br></td><td>9.5<br>-145<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Paul George</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds</td><td>over</td><td>6</td><td>58.76%</td><td>5.6<br>-143</td><td>5.5<br>-150<br></td><td>5.5<br>-145<br></td><td>5.5<br>-142<br></td><td>5.5<br>-157<br></td><td>5.5<br>-135<br></td><td>5.5<br>-137<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Michael Porter Jr.</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Rebounds</td><td>under</td><td>6</td><td>58.68%</td><td>6.4<br>-142</td><td>6.5<br>-165<br></td><td>6.5<br>-125<br></td><td>6.5<br>-144<br></td><td>6.5<br>-148<br></td><td>6.5<br>-150<br></td><td>6.5<br>-144<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Lauri Markkanen</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds + Assists</td><td>over</td><td>11</td><td>58.56%</td><td>10.7<br>-141</td><td>10.5<br>-155<br></td><td>10.5<br>-150<br></td><td></td><td>10.5<br>-133<br></td><td>10.5<br>-145<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Spencer Dinwiddie</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Assists</td><td>over</td><td>6</td><td>58.42%</td><td>5.6<br>-141</td><td>5.5<br>-160<br></td><td>5.5<br>-140<br></td><td>5.5<br>-128<br></td><td>5.5<br>-148<br></td><td>5.5<br>-145<br></td><td>5.5<br>-129<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Larry Nance Jr.</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds</td><td>under</td><td>5</td><td>58.30%</td><td>5.3<br>-140</td><td>5.5<br>-150<br></td><td>5.5<br>-135<br></td><td></td><td>5.5<br>-142<br></td><td></td><td>5.5<br>-138<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Trey Murphy III</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Turnovers</td><td>under</td><td>0.5</td><td>58.19%</td><td>0.5<br>-139</td><td>0.5<br>-145<br></td><td>0.5<br>-130<br></td><td></td><td></td><td>0.5<br>-135<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anthony Davis</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Turnovers</td><td>under</td><td>2.5</td><td>58.13%</td><td>2.5<br>-139</td><td>2.5<br>-145<br></td><td>2.5<br>-130<br></td><td></td><td></td><td>2.5<br>-135<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>D'Angelo Russell</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Assists</td><td>under</td><td>7</td><td>58.12%</td><td>7.4<br>-139</td><td>7.5<br>-140<br></td><td>7.5<br>-130<br></td><td>7.5<br>-146<br></td><td>7.5<br>-137<br></td><td></td><td>7.5<br>-138<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Paul George</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Turnovers</td><td>over</td><td>1.5</td><td>58.12%</td><td>1.5<br>-139</td><td>1.5<br>-150<br></td><td>1.5<br>-135<br></td><td></td><td></td><td>1.5<br>-135<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Mason Plumlee</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds</td><td>under</td><td>7</td><td>58.08%</td><td>7.4<br>-139</td><td>7.5<br>-145<br></td><td>7.5<br>-130<br></td><td>7.5<br>-136<br></td><td>7.5<br>-123<br></td><td>7.5<br>-135<br></td><td>7.5<br>-157<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Spencer Dinwiddie</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds + Assists</td><td>over</td><td>9</td><td>58.01%</td><td>8.6<br>-138</td><td>8.5<br>-155<br></td><td>8.5<br>-135<br></td><td>8.5<br>-118<br></td><td>8.5<br>-145<br></td><td>8.5<br>-140<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Williams</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Assists</td><td>under</td><td>4.5</td><td>58.01%</td><td>4.5<br>-138</td><td>4.5<br>-155<br></td><td>4.5<br>-135<br></td><td>4.5<br>-124<br></td><td>4.5<br>-145<br></td><td>4.5<br>-140<br></td><td>4.5<br>-131<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Joe</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Turnovers</td><td>under</td><td>0.5</td><td>57.95%</td><td>0.5<br>-138</td><td>0.5<br>-145<br></td><td>0.5<br>-130<br></td><td></td><td></td><td>0.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Zion Williamson</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds</td><td>over</td><td>6</td><td>57.88%</td><td>5.7<br>-137</td><td>5.5<br>-155<br></td><td>5.5<br>-135<br></td><td>5.5<br>-120<br></td><td>5.5<br>-142<br></td><td>5.5<br>-140<br></td><td>5.5<br>-143<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Brunson</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Turnovers</td><td>under</td><td>2.5</td><td>57.87%</td><td>2.5<br>-137</td><td>2.5<br>-145<br></td><td>2.5<br>-130<br></td><td></td><td></td><td>2.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>James Harden</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds</td><td>over</td><td>5</td><td>57.85%</td><td>4.6<br>-137</td><td>4.5<br>-150<br></td><td>4.5<br>-130<br></td><td>4.5<br>-118<br></td><td>4.5<br>-139<br></td><td>4.5<br>-135<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Turnovers</td><td>under</td><td>1.5</td><td>57.81%</td><td>1.5<br>-137</td><td></td><td></td><td></td><td></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Steals + Blocks</td><td>under</td><td>2.5</td><td>57.81%</td><td>2.5<br>-137</td><td></td><td></td><td></td><td></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Turnovers</td><td>over</td><td>1.5</td><td>57.81%</td><td>1.5<br>-137</td><td></td><td></td><td></td><td></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Steals + Blocks</td><td>over</td><td>2.5</td><td>57.81%</td><td>2.5<br>-137</td><td></td><td></td><td></td><td></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kawhi Leonard</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds + Assists</td><td>over</td><td>10</td><td>57.73%</td><td>9.6<br>-137</td><td>9.5<br>-145<br></td><td>9.5<br>-140<br></td><td>9.5<br>-140<br></td><td>9.5<br>-127<br></td><td>9.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Assists</td><td>under</td><td>10.5</td><td>57.72%</td><td>10.5<br>-137</td><td></td><td></td><td>10.5<br>-136<br></td><td></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Mason Plumlee</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds + Assists</td><td>over</td><td>9</td><td>57.72%</td><td>8.7<br>-137</td><td>8.5<br>-150<br></td><td>8.5<br>-130<br></td><td></td><td>8.5<br>-139<br></td><td>8.5<br>-135<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Brunson</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds + Assists</td><td>over</td><td>12</td><td>57.69%</td><td>11.6<br>-136</td><td>11.5<br>-145<br></td><td>11.5<br>-140<br></td><td>11.5<br>-136<br></td><td>11.5<br>-133<br></td><td>11.5<br>-135<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Herbert Jones</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Blocks</td><td>over</td><td>0.5</td><td>57.66%</td><td>0.5<br>-136</td><td></td><td>0.5<br>-130<br></td><td></td><td></td><td>0.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Cameron Johnson</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds</td><td>over</td><td>16.5</td><td>57.60%</td><td>15.8<br>-136</td><td>15.5<br>-140<br></td><td>15.5<br>-145<br></td><td></td><td>15.5<br>-129<br></td><td>15.5<br>-135<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jabari Walker</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Steals</td><td>under</td><td>0.5</td><td>57.59%</td><td>0.5<br>-136</td><td></td><td>0.5<br>-130<br></td><td></td><td></td><td>0.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Brandon Ingram</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Assists</td><td>under</td><td>6.5</td><td>57.59%</td><td>6.5<br>-136</td><td>6.5<br>-150<br></td><td>6.5<br>-125<br></td><td>6.5<br>-122<br></td><td>6.5<br>-131<br></td><td>6.5<br>-135<br></td><td>6.5<br>-133<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Mikal Bridges</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Made Threes</td><td>under</td><td>2.5</td><td>57.58%</td><td>2.5<br>-136</td><td></td><td>2.5<br>-130<br></td><td>2.5<br>-132<br></td><td></td><td>2.5<br>-135<br></td><td>2.5<br>-135<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Malcolm Brogdon</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Steals</td><td>over</td><td>0.5</td><td>57.57%</td><td>0.5<br>-136</td><td></td><td>0.5<br>-130<br></td><td></td><td>0.5<br>-135<br></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Brunson</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Assists</td><td>over</td><td>7.5</td><td>57.54%</td><td>7.5<br>-136</td><td>7.5<br>-145<br></td><td>7.5<br>-140<br></td><td>7.5<br>-124<br></td><td>7.5<br>-127<br></td><td>7.5<br>-135<br></td><td>7.5<br>-133<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points</td><td>under</td><td>7.5</td><td>57.54%</td><td>7.5<br>-136</td><td></td><td></td><td>7.5<br>-134<br></td><td></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Lonnie Walker IV</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points</td><td>under</td><td>8</td><td>57.53%</td><td>8.4<br>-135</td><td>8.5<br>-140<br></td><td>8.5<br>-145<br></td><td></td><td>8.5<br>-137<br></td><td>8.5<br>-125<br></td><td>8.5<br>-127<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Joe</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points</td><td>over</td><td>8</td><td>57.52%</td><td>7.6<br>-135</td><td>7.5<br>-145<br></td><td>7.5<br>-130<br></td><td>7.5<br>-122<br></td><td></td><td>7.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>James Harden</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds + Assists</td><td>over</td><td>14</td><td>57.49%</td><td>13.6<br>-135</td><td>13.5<br>-140<br></td><td>13.5<br>-145<br></td><td>13.5<br>-130<br></td><td>13.5<br>-135<br></td><td>13.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Nic Claxton</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds + Assists</td><td>under</td><td>13</td><td>57.49%</td><td>13.3<br>-135</td><td>13.5<br>-145<br></td><td></td><td></td><td>13.5<br>-131<br></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kentavious Caldwell-Pope</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points</td><td>under</td><td>9.5</td><td>57.43%</td><td>9.5<br>-135</td><td>9.5<br>-135<br></td><td>9.5<br>-120<br></td><td>9.5<br>-134<br></td><td>9.5<br>-145<br></td><td>9.5<br>-125<br></td><td>9.5<br>-149<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Chet Holmgren</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds</td><td>under</td><td>7.5</td><td>57.43%</td><td>7.5<br>-135</td><td>7.5<br>-145<br></td><td>7.5<br>-115<br></td><td>7.5<br>-130<br></td><td>7.5<br>-125<br></td><td>7.5<br>-135<br></td><td>7.5<br>-148<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Peyton Watson</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Blocks</td><td>over</td><td>0.5</td><td>57.41%</td><td>0.5<br>-135</td><td></td><td>0.5<br>-125<br></td><td></td><td></td><td>0.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kawhi Leonard</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Steals</td><td>under</td><td>1.5</td><td>57.40%</td><td>1.5<br>-135</td><td></td><td>1.5<br>-130<br></td><td>1.5<br>-138<br></td><td>1.5<br>-131<br></td><td>1.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Paul George</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds + Assists</td><td>over</td><td>9</td><td>57.37%</td><td>8.6<br>-135</td><td>8.5<br>-135<br></td><td>8.5<br>-140<br></td><td>8.5<br>-136<br></td><td>8.5<br>-137<br></td><td>8.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Dennis Smith Jr.</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Made Threes</td><td>under</td><td>0.5</td><td>57.34%</td><td>0.5<br>-134</td><td></td><td>0.5<br>-125<br></td><td></td><td></td><td>0.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Deandre Ayton</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds</td><td>over</td><td>9</td><td>57.33%</td><td>8.6<br>-134</td><td>8.5<br>-135<br></td><td>8.5<br>-140<br></td><td>8.5<br>-128<br></td><td>8.5<br>-145<br></td><td>8.5<br>-125<br></td><td>8.5<br>-123<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Luguentz Dort</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>16.5</td><td>57.31%</td><td>16.5<br>-134</td><td>16.5<br>-140<br></td><td>16.5<br>-130<br></td><td></td><td>16.5<br>-131<br></td><td>16.5<br>-130<br></td><td>16.5<br>-130<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Peyton Watson</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Rebounds</td><td>over</td><td>2.5</td><td>57.30%</td><td>2.5<br>-134</td><td>2.5<br>-140<br></td><td>2.5<br>-125<br></td><td></td><td></td><td>2.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Brandon Ingram</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds</td><td>over</td><td>25</td><td>57.29%</td><td>24.8<br>-134</td><td>24.5<br>-140<br></td><td>24.5<br>-135<br></td><td>25.5<br>-106<br></td><td>24.5<br>-145<br></td><td>24.5<br>-145<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Zion Williamson</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds + Assists</td><td>over</td><td>11</td><td>57.29%</td><td>10.6<br>-134</td><td>10.5<br>-140<br></td><td>10.5<br>-145<br></td><td>10.5<br>-132<br></td><td>10.5<br>-129<br></td><td>10.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anthony Davis</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Assists</td><td>over</td><td>32</td><td>57.26%</td><td>31.9<br>-134</td><td>31.5<br>-130<br></td><td>31.5<br>-130<br></td><td>32.5<br>-108<br></td><td>31.5<br>-157<br></td><td>31.5<br>-145<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anfernee Simons</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Steals</td><td>under</td><td>0.5</td><td>57.23%</td><td>0.5<br>-134</td><td></td><td>0.5<br>-140<br></td><td></td><td>0.5<br>-125<br></td><td>0.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jonas Valanciunas</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points</td><td>over</td><td>12.5</td><td>57.23%</td><td>11.7<br>-134</td><td>11.5<br>-145<br></td><td>11.5<br>-130<br></td><td>11.5<br>-120<br></td><td>11.5<br>-133<br></td><td>11.5<br>-130<br></td><td>11.5<br>-133<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Larry Nance Jr.</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds</td><td>under</td><td>11.5</td><td>57.22%</td><td>11.5<br>-134</td><td>11.5<br>-140<br></td><td>11.5<br>-125<br></td><td></td><td>11.5<br>-133<br></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Aaron Gordon</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Rebounds</td><td>over</td><td>7</td><td>57.18%</td><td>6.7<br>-134</td><td>6.5<br>-150<br></td><td>6.5<br>-135<br></td><td>6.5<br>-114<br></td><td>6.5<br>-129<br></td><td>6.5<br>-135<br></td><td>6.5<br>-137<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds</td><td>over</td><td>12</td><td>57.17%</td><td>11.8<br>-134</td><td></td><td></td><td>11.5<br>-130<br></td><td></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Brandon Ingram</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Blocks</td><td>under</td><td>0.5</td><td>57.16%</td><td>0.5<br>-133</td><td></td><td>0.5<br>-125<br></td><td></td><td></td><td>0.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Julius Randle</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Turnovers</td><td>under</td><td>3.5</td><td>57.14%</td><td>3.5<br>-133</td><td>3.5<br>-135<br></td><td>3.5<br>-125<br></td><td></td><td></td><td>3.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Josh Giddey</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>22.5</td><td>57.14%</td><td>22.5<br>-133</td><td>22.5<br>-130<br></td><td>22.5<br>-140<br></td><td>22.5<br>-130<br></td><td>22.5<br>-142<br></td><td>22.5<br>-135<br></td><td>22.5<br>-117<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jerami Grant</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Steals</td><td>over</td><td>0.5</td><td>57.13%</td><td>0.5<br>-133</td><td></td><td>0.5<br>-125<br></td><td></td><td>0.5<br>-129<br></td><td>0.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Michael Porter Jr.</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Rebounds + Assists</td><td>under</td><td>7.5</td><td>57.11%</td><td>7.5<br>-133</td><td>7.5<br>-140<br></td><td>7.5<br>-125<br></td><td></td><td>7.5<br>-135<br></td><td>7.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>John Collins</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds</td><td>over</td><td>5.5</td><td>57.10%</td><td>5.5<br>-133</td><td>5.5<br>-140<br></td><td>5.5<br>-125<br></td><td>5.5<br>-130<br></td><td>5.5<br>-125<br></td><td>5.5<br>-130<br></td><td>5.5<br>-129<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Simone Fontecchio</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Steals</td><td>under</td><td>0.5</td><td>57.08%</td><td>0.5<br>-133</td><td></td><td>0.5<br>-125<br></td><td></td><td></td><td>0.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Larry Nance Jr.</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Steals + Blocks</td><td>under</td><td>1.5</td><td>57.08%</td><td>1.5<br>-133</td><td></td><td>1.5<br>-125<br></td><td></td><td></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Julius Randle</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds + Assists</td><td>over</td><td>15</td><td>57.04%</td><td>14.7<br>-133</td><td>14.5<br>-145<br></td><td>14.5<br>-135<br></td><td>14.5<br>-113<br></td><td>14.5<br>-137<br></td><td>14.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Taurean Prince</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Assists</td><td>over</td><td>11.5</td><td>57.02%</td><td>11.5<br>-133</td><td>11.5<br>-145<br></td><td>11.5<br>-125<br></td><td></td><td>11.5<br>-131<br></td><td>11.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Malcolm Brogdon</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds + Assists</td><td>over</td><td>10</td><td>57.02%</td><td>9.6<br>-133</td><td>9.5<br>-140<br></td><td>9.5<br>-125<br></td><td>9.5<br>-130<br></td><td>9.5<br>-127<br></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>CJ McCollum</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points</td><td>over</td><td>18</td><td>57.01%</td><td>17.7<br>-133</td><td>17.5<br>-140<br></td><td>17.5<br>-140<br></td><td>18.5<br>-104<br></td><td>17.5<br>-137<br></td><td>17.5<br>-125<br></td><td>17.5<br>-137<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Cam Thomas</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>22.5</td><td>57.01%</td><td>22.4<br>-133</td><td>22.5<br>-140<br></td><td></td><td></td><td>22.5<br>-127<br></td><td>22.5<br>-125<br></td><td>22.5<br>-126<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Herbert Jones</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points</td><td>under</td><td>9</td><td>57.01%</td><td>9.5<br>-133</td><td>9.5<br>-140<br></td><td>9.5<br>-130<br></td><td>9.5<br>-128<br></td><td>9.5<br>-137<br></td><td>9.5<br>-130<br></td><td>9.5<br>-116<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Taurean Prince</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points</td><td>under</td><td>10</td><td>56.99%</td><td>10.5<br>-133</td><td>10.5<br>-135<br></td><td>10.5<br>-125<br></td><td>10.5<br>-125<br></td><td>10.5<br>-127<br></td><td>10.5<br>-125<br></td><td>10.5<br>-145<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds + Assists</td><td>over</td><td>15</td><td>56.99%</td><td>14.8<br>-133</td><td></td><td></td><td>14.5<br>-128<br></td><td></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Collin Sexton</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points</td><td>over</td><td>21.5</td><td>56.99%</td><td>20.7<br>-133</td><td>20.5<br>-140<br></td><td>20.5<br>-125<br></td><td>20.5<br>-115<br></td><td>20.5<br>-129<br></td><td>20.5<br>-130<br></td><td>20.5<br>-128<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Josh Giddey</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points</td><td>under</td><td>11.5</td><td>56.99%</td><td>11.5<br>-133</td><td>11.5<br>-140<br></td><td>11.5<br>-130<br></td><td>11.5<br>-120<br></td><td>11.5<br>-127<br></td><td>11.5<br>-130<br></td><td>11.5<br>-131<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Dorian Finney-Smith</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points</td><td>under</td><td>7</td><td>56.98%</td><td>7.4<br>-132</td><td>7.5<br>-145<br></td><td>7.5<br>-130<br></td><td>7.5<br>-124<br></td><td>7.5<br>-117<br></td><td>7.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>OG Anunoby</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Assists</td><td>over</td><td>16.5</td><td>56.96%</td><td>15.8<br>-132</td><td>15.5<br>-140<br></td><td>15.5<br>-130<br></td><td></td><td>15.5<br>-129<br></td><td>15.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Lonnie Walker IV</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds</td><td>over</td><td>10</td><td>56.96%</td><td>9.7<br>-132</td><td>9.5<br>-135<br></td><td></td><td></td><td></td><td>9.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Terance Mann</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds</td><td>over</td><td>10.5</td><td>56.96%</td><td>10.5<br>-132</td><td>10.5<br>-145<br></td><td>10.5<br>-130<br></td><td>10.5<br>-125<br></td><td>10.5<br>-127<br></td><td>10.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Christian Braun</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Steals + Blocks</td><td>over</td><td>0.5</td><td>56.94%</td><td>0.5<br>-132</td><td></td><td>0.5<br>-125<br></td><td></td><td></td><td>0.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Nikola Jokic</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points</td><td>under</td><td>28.5</td><td>56.90%</td><td>28.4<br>-132</td><td>28.5<br>-135<br></td><td>28.5<br>-120<br></td><td>27.5<br>-110<br></td><td>28.5<br>-142<br></td><td>28.5<br>-125<br></td><td>28.5<br>-147<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jonas Valanciunas</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>22.5</td><td>56.90%</td><td>22.6<br>-132</td><td>22.5<br>-140<br></td><td>22.5<br>-125<br></td><td></td><td>22.5<br>-129<br></td><td>22.5<br>-125<br></td><td>22.5<br>-128<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Cameron Johnson</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points</td><td>under</td><td>12.5</td><td>56.88%</td><td>12.5<br>-132</td><td>12.5<br>-140<br></td><td>12.5<br>-125<br></td><td></td><td>12.5<br>-127<br></td><td>12.5<br>-125<br></td><td>12.5<br>-127<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Nikola Jokic</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Made Threes</td><td>over</td><td>0.5</td><td>56.87%</td><td>0.5<br>-132</td><td></td><td>0.5<br>-125<br></td><td></td><td></td><td>0.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Chet Holmgren</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>28</td><td>56.86%</td><td>27.7<br>-132</td><td>27.5<br>-140<br></td><td>27.5<br>-140<br></td><td>27.5<br>-115<br></td><td>27.5<br>-129<br></td><td>27.5<br>-125<br></td><td>27.5<br>-126<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Dorian Finney-Smith</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds</td><td>over</td><td>11.5</td><td>56.83%</td><td>11.5<br>-132</td><td>11.5<br>-130<br></td><td>11.5<br>-130<br></td><td>11.5<br>-128<br></td><td>11.5<br>-137<br></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jabari Walker</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds + Assists</td><td>under</td><td>8.5</td><td>56.83%</td><td>8.5<br>-132</td><td>8.5<br>-135<br></td><td>8.5<br>-125<br></td><td></td><td>8.5<br>-131<br></td><td>8.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Josh Giddey</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds + Assists</td><td>under</td><td>11</td><td>56.80%</td><td>11.4<br>-132</td><td>11.5<br>-145<br></td><td>11.5<br>-130<br></td><td>11.5<br>-128<br></td><td>11.5<br>-117<br></td><td>11.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Mikal Bridges</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>30</td><td>56.80%</td><td>29.8<br>-132</td><td>29.5<br>-140<br></td><td>29.5<br>-145<br></td><td>30.5<br>-111<br></td><td>29.5<br>-127<br></td><td>29.5<br>-125<br></td><td>29.5<br>-124<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jonas Valanciunas</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Steals</td><td>under</td><td>0.5</td><td>56.80%</td><td>0.5<br>-132</td><td></td><td>0.5<br>-135<br></td><td></td><td></td><td>0.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Zion Williamson</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points</td><td>under</td><td>24.5</td><td>56.80%</td><td>24.5<br>-132</td><td>24.5<br>-140<br></td><td>24.5<br>-120<br></td><td>24.5<br>-115<br></td><td>24.5<br>-137<br></td><td>24.5<br>-130<br></td><td>24.5<br>-128<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Aaron Gordon</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Rebounds</td><td>over</td><td>22</td><td>56.79%</td><td>21.6<br>-131</td><td>21.5<br>-140<br></td><td>21.5<br>-125<br></td><td>21.5<br>-122<br></td><td>21.5<br>-129<br></td><td>21.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Brandon Ingram</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Steals + Blocks</td><td>over</td><td>1.5</td><td>56.78%</td><td>1.5<br>-131</td><td></td><td>1.5<br>-125<br></td><td></td><td></td><td>1.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jonas Valanciunas</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Steals + Blocks</td><td>over</td><td>1.5</td><td>56.78%</td><td>1.5<br>-131</td><td></td><td>1.5<br>-125<br></td><td></td><td></td><td>1.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Donte DiVincenzo</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points</td><td>under</td><td>13.5</td><td>56.78%</td><td>13.4<br>-131</td><td>13.5<br>-135<br></td><td>13.5<br>-125<br></td><td>12.5<br>-104<br></td><td>13.5<br>-157<br></td><td>13.5<br>-125<br></td><td>13.5<br>-125<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Herbert Jones</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Steals + Blocks</td><td>over</td><td>1.5</td><td>56.78%</td><td>1.5<br>-131</td><td></td><td>1.5<br>-140<br></td><td></td><td></td><td>1.5<br>-115<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Herbert Jones</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Assists</td><td>under</td><td>11.5</td><td>56.77%</td><td>11.5<br>-131</td><td>11.5<br>-140<br></td><td>11.5<br>-125<br></td><td></td><td>11.5<br>-133<br></td><td>11.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>OG Anunoby</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points</td><td>under</td><td>14.5</td><td>56.77%</td><td>14.5<br>-131</td><td>14.5<br>-135<br></td><td>14.5<br>-120<br></td><td>14.5<br>-128<br></td><td>14.5<br>-129<br></td><td>14.5<br>-125<br></td><td>14.5<br>-135<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Malcolm Brogdon</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>over</td><td>20.5</td><td>56.74%</td><td>20.5<br>-131</td><td>20.5<br>-140<br></td><td>20.5<br>-125<br></td><td>20.5<br>-122<br></td><td>20.5<br>-129<br></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Russell Westbrook</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds + Assists</td><td>under</td><td>10.5</td><td>56.73%</td><td>10.5<br>-131</td><td>10.5<br>-140<br></td><td>10.5<br>-125<br></td><td>10.5<br>-128<br></td><td>10.5<br>-129<br></td><td>10.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Taurean Prince</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds</td><td>under</td><td>13.5</td><td>56.71%</td><td>13.5<br>-131</td><td>13.5<br>-140<br></td><td>13.5<br>-130<br></td><td>13.5<br>-122<br></td><td>13.5<br>-129<br></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>22.5</td><td>56.71%</td><td>22.5<br>-131</td><td></td><td></td><td>22.5<br>-125<br></td><td></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Lonnie Walker IV</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Steals + Blocks</td><td>over</td><td>0.5</td><td>56.71%</td><td>0.5<br>-131</td><td></td><td>0.5<br>-125<br></td><td></td><td></td><td>0.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Buddy Hield</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>20.5</td><td>56.69%</td><td>20.6<br>-131</td><td>20.5<br>-140<br></td><td>20.5<br>-125<br></td><td>20.5<br>-122<br></td><td>20.5<br>-125<br></td><td>20.5<br>-125<br></td><td>20.5<br>-127<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Buddy Hield</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points</td><td>over</td><td>13.5</td><td>56.69%</td><td>13.5<br>-131</td><td>13.5<br>-140<br></td><td>13.5<br>-125<br></td><td>13.5<br>-118<br></td><td>13.5<br>-127<br></td><td>13.5<br>-125<br></td><td>13.5<br>-127<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anfernee Simons</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Assists</td><td>under</td><td>4.5</td><td>56.69%</td><td>4.5<br>-131</td><td>4.5<br>-135<br></td><td>4.5<br>-120<br></td><td>4.5<br>-144<br></td><td>4.5<br>-123<br></td><td>4.5<br>-120<br></td><td>4.5<br>-130<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Mikal Bridges</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds + Assists</td><td>under</td><td>8.5</td><td>56.68%</td><td>8.5<br>-131</td><td>8.5<br>-140<br></td><td>8.5<br>-130<br></td><td>8.5<br>-113<br></td><td>8.5<br>-129<br></td><td>8.5<br>-130<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jonas Valanciunas</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Assists</td><td>under</td><td>14.5</td><td>56.68%</td><td>14.5<br>-131</td><td>14.5<br>-140<br></td><td>14.5<br>-125<br></td><td></td><td>14.5<br>-125<br></td><td>14.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Aaron Gordon</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points</td><td>over</td><td>14.5</td><td>56.65%</td><td>14.6<br>-131</td><td>14.5<br>-135<br></td><td>14.5<br>-125<br></td><td>14.5<br>-128<br></td><td>14.5<br>-121<br></td><td>14.5<br>-125<br></td><td>14.5<br>-126<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Spencer Dinwiddie</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>22</td><td>56.63%</td><td>22.4<br>-131</td><td>22.5<br>-135<br></td><td>22.5<br>-130<br></td><td>21.5<br>-104<br></td><td>22.5<br>-127<br></td><td>22.5<br>-120<br></td><td>22.5<br>-151<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Deandre Ayton</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds + Assists</td><td>over</td><td>10</td><td>56.62%</td><td>9.6<br>-131</td><td>9.5<br>-135<br></td><td>9.5<br>-125<br></td><td></td><td>9.5<br>-129<br></td><td>9.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Malcolm Brogdon</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Assists</td><td>over</td><td>5.5</td><td>56.62%</td><td>5.5<br>-131</td><td>5.5<br>-135<br></td><td>5.5<br>-125<br></td><td>5.5<br>-115<br></td><td>5.5<br>-125<br></td><td></td><td>5.5<br>-127<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Cam Thomas</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds</td><td>over</td><td>19.5</td><td>56.60%</td><td>19.5<br>-130</td><td>19.5<br>-135<br></td><td></td><td></td><td>19.5<br>-127<br></td><td>19.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Malcolm Brogdon</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points</td><td>over</td><td>16.5</td><td>56.58%</td><td>16.5<br>-130</td><td>16.5<br>-140<br></td><td>16.5<br>-125<br></td><td>16.5<br>-110<br></td><td>16.5<br>-129<br></td><td></td><td>16.5<br>-126<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Aaron Nesmith</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Assists</td><td>over</td><td>11.5</td><td>56.58%</td><td>11.5<br>-130</td><td>11.5<br>-140<br></td><td>11.5<br>-125<br></td><td></td><td>11.5<br>-127<br></td><td>11.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Dennis Smith Jr.</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points</td><td>under</td><td>6.5</td><td>56.58%</td><td>6.5<br>-130</td><td>6.5<br>-135<br></td><td>6.5<br>-120<br></td><td></td><td></td><td>6.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Zion Williamson</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds</td><td>under</td><td>30.5</td><td>56.57%</td><td>30.5<br>-130</td><td>30.5<br>-135<br></td><td>30.5<br>-125<br></td><td>30.5<br>-118<br></td><td>30.5<br>-137<br></td><td>30.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Russell Westbrook</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Assists</td><td>over</td><td>4.5</td><td>56.56%</td><td>4.5<br>-130</td><td>4.5<br>-135<br></td><td>4.5<br>-125<br></td><td>4.5<br>-120<br></td><td>4.5<br>-125<br></td><td>4.5<br>-125<br></td><td>4.5<br>-127<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anthony Davis</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds</td><td>over</td><td>13</td><td>56.54%</td><td>12.6<br>-130</td><td>12.5<br>-135<br></td><td>12.5<br>-135<br></td><td>12.5<br>-113<br></td><td>12.5<br>-137<br></td><td>12.5<br>-125<br></td><td>12.5<br>-113<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>D'Angelo Russell</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>29.5</td><td>56.54%</td><td>30.1<br>-130</td><td>30.5<br>-135<br></td><td>30.5<br>-125<br></td><td>29.5<br>-113<br></td><td>30.5<br>-127<br></td><td>30.5<br>-125<br></td><td>29.5<br>-133<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Terance Mann</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points</td><td>over</td><td>7.5</td><td>56.54%</td><td>7.5<br>-130</td><td>7.5<br>-140<br></td><td>7.5<br>-125<br></td><td>7.5<br>-113<br></td><td>7.5<br>-125<br></td><td>7.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Simone Fontecchio</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points</td><td>under</td><td>8</td><td>56.54%</td><td>8.4<br>-130</td><td>8.5<br>-140<br></td><td>8.5<br>-130<br></td><td>8.5<br>-122<br></td><td>8.5<br>-111<br></td><td>8.5<br>-130<br></td><td>8.5<br>-121<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Josh Giddey</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds</td><td>over</td><td>6.5</td><td>56.54%</td><td>6.5<br>-130</td><td>6.5<br>-135<br></td><td>6.5<br>-120<br></td><td>6.5<br>-112<br></td><td>6.5<br>-131<br></td><td>6.5<br>-125<br></td><td>6.5<br>-133<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Brandon Ingram</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds</td><td>over</td><td>4.5</td><td>56.52%</td><td>4.5<br>-130</td><td>4.5<br>-130<br></td><td>4.5<br>-125<br></td><td>4.5<br>-118<br></td><td></td><td>4.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jamal Murray</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Rebounds</td><td>over</td><td>29</td><td>56.50%</td><td>28.7<br>-130</td><td>28.5<br>-135<br></td><td>28.5<br>-140<br></td><td>28.5<br>-115<br></td><td>28.5<br>-127<br></td><td>28.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Reggie Jackson</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Steals</td><td>under</td><td>0.5</td><td>56.49%</td><td>0.5<br>-130</td><td></td><td>0.5<br>-120<br></td><td></td><td></td><td>0.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>D'Angelo Russell</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Turnovers</td><td>over</td><td>2.5</td><td>56.49%</td><td>2.5<br>-130</td><td>2.5<br>-130<br></td><td>2.5<br>-120<br></td><td></td><td></td><td>2.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Aaron Nesmith</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Rebounds</td><td>over</td><td>13.5</td><td>56.49%</td><td>13.5<br>-130</td><td>13.5<br>-140<br></td><td>13.5<br>-125<br></td><td>13.5<br>-120<br></td><td>13.5<br>-129<br></td><td>13.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Terance Mann</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Steals</td><td>under</td><td>0.5</td><td>56.47%</td><td>0.5<br>-130</td><td></td><td>0.5<br>-120<br></td><td></td><td>0.5<br>-129<br></td><td>0.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Zion Williamson</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>34.5</td><td>56.46%</td><td>34.7<br>-130</td><td>34.5<br>-135<br></td><td>34.5<br>-125<br></td><td>35.5<br>-113<br></td><td>34.5<br>-131<br></td><td>34.5<br>-125<br></td><td>34.5<br>-125<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Buddy Hield</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Assists</td><td>under</td><td>17.5</td><td>56.45%</td><td>17.5<br>-130</td><td>17.5<br>-135<br></td><td>17.5<br>-125<br></td><td>17.5<br>-128<br></td><td>17.5<br>-127<br></td><td>17.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Hartenstein</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds</td><td>under</td><td>19.5</td><td>56.43%</td><td>19.5<br>-130</td><td></td><td></td><td>19.5<br>-122<br></td><td></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kawhi Leonard</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>34.5</td><td>56.43%</td><td>34.5<br>-130</td><td>34.5<br>-135<br></td><td>34.5<br>-125<br></td><td>34.5<br>-120<br></td><td>34.5<br>-125<br></td><td>34.5<br>-125<br></td><td>34.5<br>-124<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Josh Giddey</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>under</td><td>18.5</td><td>56.43%</td><td>18.4<br>-130</td><td>18.5<br>-140<br></td><td>18.5<br>-125<br></td><td>18.5<br>-122<br></td><td>18.5<br>-117<br></td><td>18.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Dorian Finney-Smith</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds</td><td>under</td><td>4.5</td><td>56.42%</td><td>4.5<br>-129</td><td>4.5<br>-135<br></td><td>4.5<br>-125<br></td><td>4.5<br>-118<br></td><td>4.5<br>-119<br></td><td>4.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Cameron Johnson</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>18.5</td><td>56.40%</td><td>18.5<br>-129</td><td>18.5<br>-125<br></td><td>18.5<br>-130<br></td><td></td><td>18.5<br>-129<br></td><td>18.5<br>-115<br></td><td>18.5<br>-133<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kawhi Leonard</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Turnovers</td><td>over</td><td>1.5</td><td>56.40%</td><td>1.5<br>-129</td><td>1.5<br>-130<br></td><td>1.5<br>-120<br></td><td></td><td></td><td>1.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Shai Gilgeous-Alexander</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds + Assists</td><td>over</td><td>11.5</td><td>56.40%</td><td>11.5<br>-129</td><td>11.5<br>-135<br></td><td>11.5<br>-125<br></td><td>11.5<br>-113<br></td><td>11.5<br>-135<br></td><td>11.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Williams</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Blocks</td><td>over</td><td>0.5</td><td>56.40%</td><td>0.5<br>-129</td><td></td><td>0.5<br>-120<br></td><td></td><td>0.5<br>-125<br></td><td>0.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>D'Angelo Russell</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Assists</td><td>under</td><td>27.5</td><td>56.38%</td><td>27.3<br>-129</td><td>27.5<br>-140<br></td><td>27.5<br>-125<br></td><td>26.5<br>-113<br></td><td>27.5<br>-129<br></td><td>27.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Trey Murphy III</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds</td><td>over</td><td>14.5</td><td>56.37%</td><td>14.5<br>-129</td><td>14.5<br>-140<br></td><td>14.5<br>-125<br></td><td></td><td>14.5<br>-119<br></td><td>14.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Deandre Ayton</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Assists</td><td>under</td><td>12.5</td><td>56.36%</td><td>12.5<br>-129</td><td>12.5<br>-135<br></td><td>12.5<br>-125<br></td><td></td><td>12.5<br>-125<br></td><td>12.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Zion Williamson</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Assists</td><td>over</td><td>29.5</td><td>56.36%</td><td>28.9<br>-129</td><td>28.5<br>-135<br></td><td>28.5<br>-125<br></td><td>29.5<br>-113<br></td><td>28.5<br>-133<br></td><td>28.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Williams</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Assists</td><td>over</td><td>23.5</td><td>56.36%</td><td>23.6<br>-129</td><td>23.5<br>-140<br></td><td>23.5<br>-125<br></td><td>24.5<br>-104<br></td><td>23.5<br>-137<br></td><td>23.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jamal Murray</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points</td><td>over</td><td>25.5</td><td>56.35%</td><td>24.7<br>-129</td><td>24.5<br>-135<br></td><td>24.5<br>-135<br></td><td>24.5<br>-115<br></td><td>24.5<br>-129<br></td><td>24.5<br>-120<br></td><td>24.5<br>-120<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Julius Randle</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds</td><td>over</td><td>9.5</td><td>56.33%</td><td>9.6<br>-129</td><td>9.5<br>-135<br></td><td>9.5<br>-130<br></td><td>9.5<br>-122<br></td><td>9.5<br>-125<br></td><td>9.5<br>-120<br></td><td>9.5<br>-121<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kentavious Caldwell-Pope</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Steals</td><td>over</td><td>1.5</td><td>56.33%</td><td>1.5<br>-129</td><td></td><td>1.5<br>-125<br></td><td>1.5<br>-122<br></td><td>1.5<br>-121<br></td><td>1.5<br>-140<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Chet Holmgren</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Made Threes</td><td>over</td><td>1.5</td><td>56.31%</td><td>1.5<br>-129</td><td></td><td>1.5<br>-125<br></td><td>1.5<br>-120<br></td><td></td><td>1.5<br>-130<br></td><td>1.5<br>-109<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kawhi Leonard</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points</td><td>over</td><td>24.5</td><td>56.31%</td><td>24.5<br>-129</td><td>24.5<br>-135<br></td><td>24.5<br>-125<br></td><td>24.5<br>-118<br></td><td>24.5<br>-119<br></td><td>24.5<br>-125<br></td><td>24.5<br>-124<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Malcolm Brogdon</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Assists</td><td>over</td><td>22.5</td><td>56.30%</td><td>22.5<br>-129</td><td>22.5<br>-140<br></td><td>22.5<br>-125<br></td><td>22.5<br>-108<br></td><td>22.5<br>-127<br></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Deandre Ayton</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>21.5</td><td>56.29%</td><td>21.5<br>-129</td><td>21.5<br>-140<br></td><td>21.5<br>-120<br></td><td></td><td>21.5<br>-119<br></td><td>21.5<br>-125<br></td><td>21.5<br>-110<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Michael Porter Jr.</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Assists</td><td>under</td><td>17.5</td><td>56.28%</td><td>17.5<br>-129</td><td>17.5<br>-135<br></td><td>17.5<br>-120<br></td><td></td><td>17.5<br>-119<br></td><td>17.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>CJ McCollum</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds + Assists</td><td>under</td><td>9.5</td><td>56.28%</td><td>9.5<br>-129</td><td>9.5<br>-150<br></td><td>9.5<br>-110<br></td><td>9.5<br>-115<br></td><td>9.5<br>-117<br></td><td>9.5<br>-135<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Trey Murphy III</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>16.5</td><td>56.28%</td><td>16.5<br>-129</td><td>16.5<br>-130<br></td><td>16.5<br>-120<br></td><td></td><td>16.5<br>-117<br></td><td>16.5<br>-120<br></td><td>16.5<br>-134<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Malcolm Brogdon</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>26.5</td><td>56.27%</td><td>26.5<br>-129</td><td>26.5<br>-135<br></td><td>26.5<br>-125<br></td><td>26.5<br>-113<br></td><td>26.5<br>-121<br></td><td></td><td>26.5<br>-125<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Michael Porter Jr.</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Blocks</td><td>over</td><td>0.5</td><td>56.27%</td><td>0.5<br>-129</td><td></td><td>0.5<br>-120<br></td><td></td><td>0.5<br>-123<br></td><td>0.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anfernee Simons</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points</td><td>under</td><td>21.5</td><td>56.27%</td><td>21.5<br>-129</td><td>21.5<br>-135<br></td><td>21.5<br>-120<br></td><td>21.5<br>-118<br></td><td>21.5<br>-123<br></td><td>21.5<br>-125<br></td><td>21.5<br>-125<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Cam Thomas</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Assists</td><td>over</td><td>19.5</td><td>56.26%</td><td>19.5<br>-129</td><td>19.5<br>-135<br></td><td></td><td></td><td>19.5<br>-123<br></td><td>19.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Donte DiVincenzo</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>20.5</td><td>56.26%</td><td>20.4<br>-129</td><td>20.5<br>-135<br></td><td>20.5<br>-120<br></td><td>19.5<br>-115<br></td><td>20.5<br>-127<br></td><td>20.5<br>-125<br></td><td>20.5<br>-123<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Paul George</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>33.5</td><td>56.26%</td><td>33.6<br>-129</td><td>33.5<br>-130<br></td><td>33.5<br>-125<br></td><td>34.5<br>-108<br></td><td>33.5<br>-123<br></td><td>33.5<br>-120<br></td><td>33.5<br>-145<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Lauri Markkanen</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>35.5</td><td>56.25%</td><td>35.5<br>-129</td><td>35.5<br>-135<br></td><td>35.5<br>-120<br></td><td></td><td>35.5<br>-119<br></td><td>35.5<br>-120<br></td><td>35.5<br>-122<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Nic Claxton</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>26.5</td><td>56.25%</td><td>26.6<br>-129</td><td>26.5<br>-130<br></td><td></td><td></td><td>26.5<br>-123<br></td><td></td><td>26.5<br>-115<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Nic Claxton</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points</td><td>under</td><td>13.5</td><td>56.24%</td><td>13.5<br>-129</td><td>13.5<br>-135<br></td><td></td><td>13.5<br>-110<br></td><td>13.5<br>-119<br></td><td></td><td>13.5<br>-123<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Luguentz Dort</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Assists</td><td>over</td><td>12.5</td><td>56.24%</td><td>12.5<br>-129</td><td>12.5<br>-135<br></td><td>12.5<br>-125<br></td><td></td><td>12.5<br>-121<br></td><td>12.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Zion Williamson</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Steals + Blocks</td><td>over</td><td>1.5</td><td>56.22%</td><td>1.5<br>-128</td><td></td><td>1.5<br>-120<br></td><td></td><td></td><td>1.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Pascal Siakam</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Assists</td><td>over</td><td>25.5</td><td>56.21%</td><td>25.6<br>-128</td><td>25.5<br>-135<br></td><td>25.5<br>-120<br></td><td>26.5<br>-122<br></td><td>25.5<br>-123<br></td><td>25.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Julius Randle</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds</td><td>under</td><td>35.5</td><td>56.21%</td><td>35.5<br>-128</td><td>35.5<br>-135<br></td><td>35.5<br>-125<br></td><td>35.5<br>-115<br></td><td>35.5<br>-125<br></td><td>35.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kentavious Caldwell-Pope</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Rebounds</td><td>under</td><td>12.5</td><td>56.20%</td><td>12.4<br>-128</td><td>12.5<br>-135<br></td><td>12.5<br>-120<br></td><td>12.5<br>-130<br></td><td>12.5<br>-123<br></td><td>12.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Brunson</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>40.5</td><td>56.20%</td><td>40.5<br>-128</td><td>40.5<br>-130<br></td><td>40.5<br>-110<br></td><td>40.5<br>-120<br></td><td>40.5<br>-127<br></td><td>40.5<br>-120<br></td><td>40.5<br>-141<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Deandre Ayton</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>under</td><td>21</td><td>56.19%</td><td>20.7<br>-128</td><td>20.5<br>-140<br></td><td>20.5<br>-110<br></td><td>21.5<br>-125<br></td><td>20.5<br>-119<br></td><td>20.5<br>-130<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Cameron Johnson</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds</td><td>over</td><td>3.5</td><td>56.19%</td><td>3.5<br>-128</td><td>3.5<br>-130<br></td><td>3.5<br>-120<br></td><td></td><td>3.5<br>-119<br></td><td>3.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Williams</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>over</td><td>23.5</td><td>56.19%</td><td>23.6<br>-128</td><td>23.5<br>-135<br></td><td>23.5<br>-125<br></td><td>24.5<br>-102<br></td><td>23.5<br>-137<br></td><td>23.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jabari Walker</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points</td><td>under</td><td>9.5</td><td>56.18%</td><td>9.5<br>-128</td><td>9.5<br>-135<br></td><td>9.5<br>-120<br></td><td>9.5<br>-115<br></td><td>9.5<br>-129<br></td><td>9.5<br>-120<br></td><td>9.5<br>-124<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Julius Randle</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>40</td><td>56.18%</td><td>40.5<br>-128</td><td>40.5<br>-130<br></td><td>40.5<br>-135<br></td><td>40.5<br>-120<br></td><td>40.5<br>-119<br></td><td>40.5<br>-120<br></td><td>40.5<br>-119<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kenrich Williams</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Made Threes</td><td>under</td><td>0.5</td><td>56.18%</td><td>0.5<br>-128</td><td></td><td>0.5<br>-120<br></td><td></td><td></td><td>0.5<br>-115<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Chet Holmgren</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds + Assists</td><td>under</td><td>10.5</td><td>56.17%</td><td>10.5<br>-128</td><td>10.5<br>-130<br></td><td>10.5<br>-120<br></td><td>10.5<br>-128<br></td><td>10.5<br>-117<br></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Josh Giddey</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Assists</td><td>over</td><td>15.5</td><td>56.17%</td><td>15.6<br>-128</td><td>15.5<br>-130<br></td><td>15.5<br>-120<br></td><td>15.5<br>-125<br></td><td>15.5<br>-137<br></td><td>15.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Aaron Gordon</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>25</td><td>56.16%</td><td>24.6<br>-128</td><td>24.5<br>-130<br></td><td>24.5<br>-130<br></td><td>24.5<br>-113<br></td><td>24.5<br>-115<br></td><td>24.5<br>-120<br></td><td>24.5<br>-138<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Austin Reaves</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>26.5</td><td>56.16%</td><td>26.5<br>-128</td><td>26.5<br>-130<br></td><td>26.5<br>-120<br></td><td>26.5<br>-122<br></td><td>26.5<br>-133<br></td><td>26.5<br>-120<br></td><td>26.5<br>-121<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>OG Anunoby</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>21</td><td>56.14%</td><td>21.4<br>-128</td><td>21.5<br>-135<br></td><td>21.5<br>-120<br></td><td></td><td>21.5<br>-117<br></td><td>21.5<br>-120<br></td><td>21.5<br>-123<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kris Dunn</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds + Assists</td><td>over</td><td>7.5</td><td>56.14%</td><td>7.5<br>-128</td><td>7.5<br>-130<br></td><td>7.5<br>-115<br></td><td>7.5<br>-132<br></td><td>7.5<br>-125<br></td><td>7.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Nikola Jokic</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Assists</td><td>under</td><td>37.5</td><td>56.12%</td><td>37.4<br>-128</td><td>37.5<br>-130<br></td><td>37.5<br>-120<br></td><td>36.5<br>-113<br></td><td>37.5<br>-123<br></td><td>37.5<br>-135<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Austin Reaves</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Assists</td><td>over</td><td>22.5</td><td>56.12%</td><td>22.5<br>-128</td><td>22.5<br>-130<br></td><td>22.5<br>-115<br></td><td>22.5<br>-125<br></td><td>22.5<br>-131<br></td><td>22.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Chet Holmgren</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points</td><td>under</td><td>17.5</td><td>56.10%</td><td>17.5<br>-128</td><td>17.5<br>-135<br></td><td>17.5<br>-125<br></td><td>17.5<br>-115<br></td><td>17.5<br>-121<br></td><td>17.5<br>-120<br></td><td>17.5<br>-123<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Dorian Finney-Smith</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Turnovers</td><td>under</td><td>0.5</td><td>56.10%</td><td>0.5<br>-128</td><td>0.5<br>-135<br></td><td>0.5<br>-115<br></td><td></td><td></td><td>0.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Terance Mann</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Turnovers</td><td>over</td><td>0.5</td><td>56.10%</td><td>0.5<br>-128</td><td>0.5<br>-130<br></td><td>0.5<br>-120<br></td><td></td><td></td><td>0.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Shai Gilgeous-Alexander</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>under</td><td>37.5</td><td>56.09%</td><td>37.5<br>-128</td><td>37.5<br>-135<br></td><td>37.5<br>-120<br></td><td>37.5<br>-118<br></td><td>37.5<br>-127<br></td><td>37.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Mikal Bridges</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Rebounds</td><td>over</td><td>4.5</td><td>56.09%</td><td>4.5<br>-128</td><td>4.5<br>-135<br></td><td>4.5<br>-120<br></td><td>4.5<br>-115<br></td><td>4.5<br>-123<br></td><td>4.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Russell Westbrook</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds</td><td>under</td><td>17.5</td><td>56.09%</td><td>17.5<br>-128</td><td>17.5<br>-130<br></td><td>17.5<br>-120<br></td><td>17.5<br>-125<br></td><td>17.5<br>-125<br></td><td>17.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Brandon Ingram</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Assists</td><td>over</td><td>26.5</td><td>56.09%</td><td>26.5<br>-128</td><td>26.5<br>-130<br></td><td>26.5<br>-115<br></td><td>26.5<br>-122<br></td><td>26.5<br>-133<br></td><td>26.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jerami Grant</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Blocks</td><td>under</td><td>0.5</td><td>56.08%</td><td>0.5<br>-128</td><td></td><td>0.5<br>-120<br></td><td></td><td>0.5<br>-117<br></td><td>0.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Zion Williamson</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Turnovers</td><td>over</td><td>2.5</td><td>56.08%</td><td>2.5<br>-128</td><td>2.5<br>-125<br></td><td>2.5<br>-115<br></td><td></td><td></td><td>2.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Reggie Jackson</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Rebounds</td><td>over</td><td>10.5</td><td>56.08%</td><td>10.5<br>-128</td><td>10.5<br>-140<br></td><td>10.5<br>-125<br></td><td></td><td>10.5<br>-111<br></td><td>10.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kawhi Leonard</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds</td><td>under</td><td>31.5</td><td>56.07%</td><td>31.5<br>-128</td><td>31.5<br>-130<br></td><td>31.5<br>-120<br></td><td>31.5<br>-122<br></td><td>31.5<br>-127<br></td><td>31.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jalen Williams</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds + Assists</td><td>over</td><td>8.5</td><td>56.07%</td><td>8.5<br>-128</td><td>8.5<br>-130<br></td><td>8.5<br>-120<br></td><td>8.5<br>-118<br></td><td>8.5<br>-131<br></td><td>8.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Chet Holmgren</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>over</td><td>24.5</td><td>56.07%</td><td>24.6<br>-128</td><td>24.5<br>-135<br></td><td>24.5<br>-125<br></td><td>24.5<br>-118<br></td><td>24.5<br>-121<br></td><td>24.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anfernee Simons</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>29.5</td><td>56.06%</td><td>29.4<br>-128</td><td>29.5<br>-135<br></td><td>29.5<br>-120<br></td><td>28.5<br>-102<br></td><td>29.5<br>-123<br></td><td>29.5<br>-120<br></td><td>29.5<br>-137<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kentavious Caldwell-Pope</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Assists</td><td>over</td><td>11.5</td><td>56.06%</td><td>11.5<br>-128</td><td>11.5<br>-140<br></td><td>11.5<br>-125<br></td><td>11.5<br>-111<br></td><td>11.5<br>-127<br></td><td>11.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Trey Murphy III</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Made Threes</td><td>under</td><td>2.5</td><td>56.06%</td><td>2.5<br>-128</td><td></td><td>2.5<br>-125<br></td><td>2.5<br>-108<br></td><td></td><td>2.5<br>-125<br></td><td>2.5<br>-122<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anthony Davis</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>45</td><td>56.04%</td><td>44.7<br>-128</td><td>44.5<br>-135<br></td><td>44.5<br>-130<br></td><td>45.5<br>-102<br></td><td>44.5<br>-142<br></td><td>44.5<br>-120<br></td><td>44.5<br>-109<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Nic Claxton</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Assists</td><td>under</td><td>15.5</td><td>56.04%</td><td>15.5<br>-128</td><td>15.5<br>-130<br></td><td></td><td></td><td>15.5<br>-115<br></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anfernee Simons</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Assists</td><td>over</td><td>25.5</td><td>56.04%</td><td>25.5<br>-128</td><td>25.5<br>-135<br></td><td>25.5<br>-120<br></td><td>25.5<br>-115<br></td><td>25.5<br>-123<br></td><td>25.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Trey Murphy III</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points</td><td>over</td><td>11.5</td><td>56.03%</td><td>11.5<br>-127</td><td>11.5<br>-140<br></td><td>11.5<br>-125<br></td><td>11.5<br>-110<br></td><td>11.5<br>-121<br></td><td>11.5<br>-125<br></td><td>11.5<br>-111<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Collin Sexton</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds</td><td>over</td><td>2.5</td><td>56.00%</td><td>2.5<br>-127</td><td>2.5<br>-130<br></td><td>2.5<br>-120<br></td><td>2.5<br>-112<br></td><td></td><td>2.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Lauri Markkanen</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds</td><td>over</td><td>34</td><td>56.00%</td><td>33.7<br>-127</td><td>33.5<br>-130<br></td><td>33.5<br>-140<br></td><td>33.5<br>-113<br></td><td>33.5<br>-123<br></td><td>33.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Luguentz Dort</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>over</td><td>15.5</td><td>56.00%</td><td>15.5<br>-127</td><td>15.5<br>-135<br></td><td>15.5<br>-120<br></td><td>15.5<br>-118<br></td><td>15.5<br>-123<br></td><td>15.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jonas Valanciunas</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Rebounds + Assists</td><td>over</td><td>10.5</td><td>55.98%</td><td>10.5<br>-127</td><td>10.5<br>-130<br></td><td>10.5<br>-125<br></td><td></td><td>10.5<br>-123<br></td><td>10.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Donte DiVincenzo</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds</td><td>under</td><td>17.5</td><td>55.97%</td><td>17.4<br>-127</td><td>17.5<br>-135<br></td><td>17.5<br>-120<br></td><td>16.5<br>-113<br></td><td>17.5<br>-127<br></td><td>17.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Donte DiVincenzo</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Assists</td><td>under</td><td>16.5</td><td>55.97%</td><td>16.4<br>-127</td><td>16.5<br>-135<br></td><td>16.5<br>-125<br></td><td>15.5<br>-111<br></td><td>16.5<br>-129<br></td><td>16.5<br>-125<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Norman Powell</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Assists</td><td>over</td><td>12.5</td><td>55.95%</td><td>12.5<br>-127</td><td>12.5<br>-130<br></td><td>12.5<br>-120<br></td><td></td><td>12.5<br>-127<br></td><td>12.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Russell Westbrook</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Rebounds</td><td>under</td><td>5.5</td><td>55.95%</td><td>5.5<br>-127</td><td>5.5<br>-125<br></td><td>5.5<br>-115<br></td><td>5.5<br>-115<br></td><td>5.5<br>-119<br></td><td>5.5<br>-120<br></td><td>5.5<br>-142<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Brandon Ingram</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points</td><td>under</td><td>20.5</td><td>55.93%</td><td>20.5<br>-127</td><td>20.5<br>-140<br></td><td>20.5<br>-110<br></td><td>20.5<br>-114<br></td><td>20.5<br>-117<br></td><td>20.5<br>-125<br></td><td>20.5<br>-128<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Kawhi Leonard</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Assists</td><td>over</td><td>3.5</td><td>55.93%</td><td>3.5<br>-127</td><td>3.5<br>-130<br></td><td>3.5<br>-120<br></td><td>3.5<br>-115<br></td><td>3.5<br>-125<br></td><td>3.5<br>-120<br></td><td>3.5<br>-118<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anthony Davis</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds</td><td>over</td><td>41</td><td>55.92%</td><td>40.6<br>-127</td><td>40.5<br>-125<br></td><td>40.5<br>-130<br></td><td>40.5<br>-115<br></td><td>40.5<br>-133<br></td><td>40.5<br>-110<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>D'Angelo Russell</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Rebounds</td><td>under</td><td>22.5</td><td>55.92%</td><td>22.5<br>-127</td><td>22.5<br>-130<br></td><td>22.5<br>-120<br></td><td>22.5<br>-122<br></td><td>22.5<br>-121<br></td><td>22.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Mikal Bridges</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds</td><td>under</td><td>26.5</td><td>55.92%</td><td>26.5<br>-127</td><td>26.5<br>-135<br></td><td>26.5<br>-120<br></td><td>26.5<br>-115<br></td><td>26.5<br>-123<br></td><td>26.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>CJ McCollum</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Blocks</td><td>over</td><td>0.5</td><td>55.91%</td><td>0.5<br>-127</td><td></td><td>0.5<br>-115<br></td><td></td><td></td><td>0.5<br>-115<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Lauri Markkanen</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Blocks</td><td>under</td><td>0.5</td><td>55.91%</td><td>0.5<br>-127</td><td></td><td>0.5<br>-115<br></td><td></td><td></td><td>0.5<br>-115<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jerami Grant</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>over</td><td>22.5</td><td>55.90%</td><td>22.5<br>-127</td><td>22.5<br>-130<br></td><td>22.5<br>-120<br></td><td>22.5<br>-125<br></td><td>22.5<br>-117<br></td><td>22.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Cameron Johnson</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Assists</td><td>over</td><td>14.5</td><td>55.88%</td><td>14.5<br>-127</td><td>14.5<br>-130<br></td><td>14.5<br>-120<br></td><td></td><td>14.5<br>-125<br></td><td>14.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Isaiah Joe</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>under</td><td>10.5</td><td>55.87%</td><td>10.5<br>-127</td><td>10.5<br>-135<br></td><td>10.5<br>-120<br></td><td></td><td>10.5<br>-121<br></td><td>10.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Aaron Gordon</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Rebounds + Assists</td><td>under</td><td>9.5</td><td>55.85%</td><td>9.5<br>-127</td><td>9.5<br>-130<br></td><td>9.5<br>-110<br></td><td>9.5<br>-130<br></td><td>9.5<br>-115<br></td><td></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Buddy Hield</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Rebounds</td><td>under</td><td>3.5</td><td>55.84%</td><td>3.5<br>-126</td><td>3.5<br>-135<br></td><td>3.5<br>-115<br></td><td>3.5<br>-110<br></td><td>3.5<br>-123<br></td><td>3.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Michael Porter Jr.</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Made Threes</td><td>under</td><td>2.5</td><td>55.84%</td><td>2.5<br>-126</td><td></td><td>2.5<br>-110<br></td><td>2.5<br>-113<br></td><td></td><td>2.5<br>-125<br></td><td>2.5<br>-124<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Nikola Jokic</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points + Rebounds</td><td>under</td><td>40.5</td><td>55.83%</td><td>40.4<br>-126</td><td>40.5<br>-130<br></td><td>40.5<br>-120<br></td><td>39.5<br>-108<br></td><td>40.5<br>-131<br></td><td>40.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Lauri Markkanen</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Blocks</td><td>over</td><td>0.5</td><td>55.83%</td><td>0.5<br>-126</td><td></td><td>0.5<br>-115<br></td><td></td><td></td><td>0.5<br>-115<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>CJ McCollum</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds + Assists</td><td>over</td><td>27.5</td><td>55.83%</td><td>27.5<br>-126</td><td>27.5<br>-125<br></td><td>27.5<br>-120<br></td><td>27.5<br>-120<br></td><td>27.5<br>-131<br></td><td>27.5<br>-110<br></td><td>27.5<br>-131<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Deandre Ayton</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points</td><td>over</td><td>11.5</td><td>55.83%</td><td>11.5<br>-126</td><td>11.5<br>-125<br></td><td>11.5<br>-115<br></td><td>11.5<br>-122<br></td><td>11.5<br>-123<br></td><td>11.5<br>-115<br></td><td>11.5<br>-134<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>CJ McCollum</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Blocks</td><td>under</td><td>0.5</td><td>55.83%</td><td>0.5<br>-126</td><td></td><td>0.5<br>-115<br></td><td></td><td></td><td>0.5<br>-115<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jamal Murray</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Rebounds + Assists</td><td>over</td><td>11.5</td><td>55.83%</td><td>11.6<br>-126</td><td>11.5<br>-140<br></td><td>11.5<br>-115<br></td><td>11.5<br>-102<br></td><td>11.5<br>-127<br></td><td>11.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Larry Nance Jr.</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Steals + Blocks</td><td>over</td><td>1.5</td><td>55.82%</td><td>1.5<br>-126</td><td></td><td>1.5<br>-105<br></td><td></td><td></td><td></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jamal Murray</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Assists</td><td>under</td><td>7.5</td><td>55.80%</td><td>7.6<br>-126</td><td>7.5<br>-110<br></td><td>7.5<br>-130<br></td><td>7.5<br>-130<br></td><td>7.5<br>-137<br></td><td>7.5<br>-110<br></td><td>7.5<br>-117<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anfernee Simons</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Rebounds + Assists</td><td>over</td><td>7.5</td><td>55.80%</td><td>7.5<br>-126</td><td>7.5<br>-135<br></td><td>7.5<br>-120<br></td><td>7.5<br>-104<br></td><td>7.5<br>-129<br></td><td>7.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Russell Westbrook</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Steals + Blocks</td><td>under</td><td>1.5</td><td>55.79%</td><td>1.5<br>-126</td><td></td><td>1.5<br>-120<br></td><td></td><td>1.5<br>-117<br></td><td>1.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Anthony Davis</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points</td><td>over</td><td>27.5</td><td>55.79%</td><td>27.5<br>-126</td><td>27.5<br>-125<br></td><td>27.5<br>-130<br></td><td>27.5<br>-120<br></td><td>27.5<br>-131<br></td><td>27.5<br>-110<br></td><td>27.5<br>-117<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Aaron Nesmith</td><td>1/23 07:00 PM</td><td>Denver Nuggets @ Indiana Pacers</td><td>Player Points</td><td>under</td><td>10.5</td><td>55.79%</td><td>10.5<br>-126</td><td>10.5<br>-130<br></td><td>10.5<br>-120<br></td><td>10.5<br>-120<br></td><td>10.5<br>-121<br></td><td>10.5<br>-120<br></td><td>10.5<br>-117<br></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Shai Gilgeous-Alexander</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Steals + Blocks</td><td>under</td><td>2.5</td><td>55.78%</td><td>2.5<br>-126</td><td></td><td>2.5<br>-120<br></td><td></td><td>2.5<br>-115<br></td><td>2.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Deandre Ayton</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Steals + Blocks</td><td>under</td><td>1.5</td><td>55.78%</td><td>1.5<br>-126</td><td></td><td>1.5<br>-120<br></td><td></td><td>1.5<br>-115<br></td><td>1.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Collin Sexton</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds</td><td>over</td><td>23.5</td><td>55.78%</td><td>23.5<br>-126</td><td>23.5<br>-135<br></td><td>23.5<br>-120<br></td><td>23.5<br>-115<br></td><td>23.5<br>-117<br></td><td>23.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jabari Walker</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Points + Rebounds</td><td>over</td><td>16.5</td><td>55.78%</td><td>16.5<br>-126</td><td>16.5<br>-130<br></td><td>16.5<br>-120<br></td><td>16.5<br>-120<br></td><td>16.5<br>-117<br></td><td>16.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Jonas Valanciunas</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Rebounds</td><td>over</td><td>20.5</td><td>55.78%</td><td>20.6<br>-126</td><td>20.5<br>-135<br></td><td>20.5<br>-120<br></td><td>20.5<br>-113<br></td><td>20.5<br>-119<br></td><td>20.5<br>-120<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Russell Westbrook</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Points + Assists</td><td>under</td><td>16.5</td><td>55.78%</td><td>16.5<br>-126</td><td>16.5<br>-130<br></td><td>16.5<br>-115<br></td><td>16.5<br>-125<br></td><td>16.5<br>-117<br></td><td>16.5<br>-120<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Nic Claxton</td><td>1/23 07:30 PM</td><td>New York Knicks @ Brooklyn Nets</td><td>Player Points + Rebounds + Assists</td><td>under</td><td>26.5</td><td>55.78%</td><td>26.6<br>-126</td><td>26.5<br>-125<br></td><td></td><td></td><td>26.5<br>-111<br></td><td></td><td>26.5<br>-115<br></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>CJ McCollum</td><td>1/23 08:00 PM</td><td>Utah Jazz @ New Orleans Pelicans</td><td>Player Points + Assists</td><td>under</td><td>23.5</td><td>55.78%</td><td>23.5<br>-126</td><td>23.5<br>-140<br></td><td>23.5<br>-125<br></td><td>23.5<br>-113<br></td><td>23.5<br>-104<br></td><td>23.5<br>-125<br></td><td></td></tr><tr class="odd"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>Deandre Ayton</td><td>1/23 08:00 PM</td><td>Portland Trail Blazers @ Oklahoma City Thunder</td><td>Player Steals</td><td>over</td><td>0.5</td><td>55.78%</td><td>0.5<br>-126</td><td></td><td>0.5<br>-115<br></td><td></td><td>0.5<br>-123<br></td><td>0.5<br>-115<br></td><td></td></tr><tr class="even"><td class="sorting_1 dtfc-fixed-left" style="left: 0px; position: sticky;"><input type="checkbox" id="" class="row-checkbox-nba"></td><td>James Harden</td><td>1/23 10:00 PM</td><td>Los Angeles Lakers @ Los Angeles Clippers</td><td>Player Made Threes</td><td>over</td><td>2.5</td><td>55.78%</td><td>2.5<br>-126</td><td></td><td>2.5<br>-115<br></td><td>2.5<br>-128<br></td><td></td><td>2.5<br>-115<br></td><td>2.5<br>-117<br></td></tr></tbody>
                        </table>'''  # Replace with the exact URL

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the table by ID or other attributes
    table = soup.find('table', {'id': 'nba_table'})  # Adjust if necessary

    # Extract rows from the table
    rows = table.find_all('tr')

    # Extract header and data from rows
    headers = [header.text.strip() for header in rows[0].find_all('th')]
    data = [[td.text.strip() for td in row.find_all('td')] for row in rows[1:]]

    # Create DataFrame
    df = pd.DataFrame(data, columns=headers)

    print(df.head())  # Display first few rows of the DataFrame
else:
    print("Failed to retrieve webpage")
# Out:
# Empty DataFrame
# Columns: [, Player Name, Date, Match Up, Market Name, O/U, PrizePicks, Underdog Fantasy, Parlay Play, Sleeper, Prob%, MySpari, Fliff, DraftKings, FanDuel, Caesars, BetMGM, Pinnacle]
# Index: []

# %%
soup = BeautifulSoup(response.content, 'html.parser')
nba_picks = soup.find_all('div', {'class': 'dataTables_scrollBody'})

# %%
soup.find_all('div', )
# Out:
# [<div id="page-container">
#  <div class="et-boc" id="et-boc">
#  <header class="et-l et-l--header">
#  <div class="et_builder_inner_content et_pb_gutters3">
#  <div class="et_pb_section et_pb_section_0_tb_header et_pb_with_background et_section_regular">
#  <div class="et_pb_row et_pb_row_0_tb_header">
#  <div class="et_pb_column et_pb_column_4_4 et_pb_column_0_tb_header et_pb_css_mix_blend_mode_passthrough et-last-child">
#  <div class="et_pb_module et_pb_text et_pb_text_0_tb_header et_pb_text_align_center et_pb_bg_layout_light">
#  <div class="et_pb_text_inner">
#  <p><a href="https://myspari.com/join-spari/" rel="noopener" style="color:#ffffff;" target="_blank">JOIN
#                                                  OUR DUBCLUB TO UNLOCK ALL PREMIUM PICKS &amp; TOOLS</a></p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="et_pb_section et_pb_section_1_tb_header et_pb_with_background et_section_regular et_pb_section--with-menu">
# ...

# %%
nba = soup.find_all('div', {'class': "tab-content"})[6]

# %%
nba
# Out:
# <div class="tab-content" id="NBA">
# <select id="selection_line_nba">
# <option selected="" value="">Select Line</option>
# <option value="over">
#                             Over
#                         </option>
# <option value="under">
#                             Under
#                         </option>
# </select>
# <select id="team_filter_nba">
# <option selected="" value="">Select Team</option>
# <option value="Los Angeles Clippers">
#                             Los Angeles Clippers</option>
# <option value="Oklahoma City Thunder">
#                             Oklahoma City Thunder</option>
# <option value="New Orleans Pelicans">
#                             New Orleans Pelicans</option>
# <option value="Brooklyn Nets">
#                             Brooklyn Nets</option>
# <option value="Indiana Pacers">
#                             Indiana Pacers</option>
# <option value="Los Angeles Lakers">
#                             Los Angeles Lakers</option>
# ...
